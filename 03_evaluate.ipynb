# %%
# %matplotlib inline

# %%
import numpy as np
import matplotlib.pyplot as plt
import glob
import os.path
import pretty_midi

# %% [markdown]
# ### Generate ground truth labels

# %%
def importScoreInfo(scoreDir):
    d = {}
    for csvfile in glob.glob("{}/p*.scoreinfo.csv".format(scoreDir)):
        pieceStr = os.path.basename(csvfile).split('.')[0]  # e.g. 'p7'
        d[pieceStr] = {}
        with open(csvfile, 'r') as f:
            next(f) # skip header
            for line in f:
                parts = line.rstrip().split(',')
                linenum = int(parts[0])
                startmeasure = int(parts[1])
                endmeasure = int(parts[2])
                d[pieceStr][linenum] = (startmeasure, endmeasure)
    return d

# %%
scoreDir = 'data/score_info'
scoreInfo = importScoreInfo(scoreDir)

# %%
def importMidiInfo(midiInfoDir, midiDir):
    d = {}
    for csvfile in glob.glob("{}/p*_midinfo.csv".format(midiInfoDir)):
        pieceStr = os.path.basename(csvfile).split('_')[0]  # e.g. 'p7'
        d[pieceStr] = {}
        with open(csvfile, 'r') as f:
            for line in f:
                parts = line.rstrip().split(',')
                measure = int(parts[0])
                time = float(parts[1])
                d[pieceStr][measure] = time
        
        # add an additional entry to indicate the total duration
        midfile = "{}/{}.mid".format(midiDir, pieceStr)
        mid = pretty_midi.PrettyMIDI(midfile)
        totalDur = mid.get_piano_roll().shape[1] * .01 # default fs = 100
        d[pieceStr][measure+1] = totalDur
                
    return d

# %%
midiInfoDir = 'data/midi_info'
midiDir = 'data/midi'
midiInfo = importMidiInfo(midiInfoDir, midiDir)
# Out:
# /home/tjtsai/anaconda2/envs/SheetMidiRetrieval/lib/python3.6/site-packages/pretty_midi/pretty_midi.py:100: RuntimeWarning: Tempo, Key or Time signature change events found on non-zero tracks.  This is not a valid type 0 or type 1 MIDI file.  Tempo, Key or Time Signature may be wrong.
#   RuntimeWarning)

# %%
def getQueryGroundTruth(infile, multMatchFile, scoreInfo, midiInfo):
    # infers ground truth timestamps for each query
    d = {}
    with open(infile, 'r') as fin: 
        next(fin) # skip header
        for line in fin:

            # get start, end lines
            parts = line.rstrip().split(',')  # e.g. 'p1_q1,0,3'
            queryStr = parts[0]
            startLine = int(parts[1])
            endLine = int(parts[2])

            # infer start, end measure
            pieceStr = queryStr.split('_')[0]
            #print("%s,%s,%s" % (queryStr, startLine,endLine))            
            startMeasure = scoreInfo[pieceStr][startLine][0]
            endMeasure = scoreInfo[pieceStr][endLine][1]

            # infer start, end time
            #print("%s,%s,%s" % (queryStr, startMeasure, endMeasure))
            startTime = midiInfo[pieceStr][startMeasure]
            endTime = midiInfo[pieceStr][endMeasure+1] # ends on downbeat of next measure

            d[queryStr] = [(startTime, endTime, startMeasure, endMeasure, startLine, endLine)]

    addMultipleMatches(d, multMatchFile, scoreInfo, midiInfo)
            
    return d

# %%
def addMultipleMatches(d, multMatchFile, scoreInfo, midiInfo):
    # some queries match more than 1 segment of the score, these are indicated in multMatchFile
    with open(multMatchFile, 'r') as f:
        for line in f:
            
            # parse line 
            parts = line.rstrip().split(',')  # e.g. 'p31_q8,L3m6,L5m1'
            queryStr = parts[0]
            pieceStr = queryStr.split('_')[0]
            startStr = parts[1]
            endStr = parts[2]
            
            # infer start, end measure
            startLine = int(startStr.split('m')[0][1:])
            endLine = int(endStr.split('m')[0][1:])
            startOffset = int(startStr.split('m')[1])
            endOffset = int(endStr.split('m')[1])
            startMeasure = scoreInfo[pieceStr][startLine][0] + startOffset - 1
            endMeasure = scoreInfo[pieceStr][endLine][0] + endOffset - 1
            
            # infer start, end time
            startTime = midiInfo[pieceStr][startMeasure]
            endTime = midiInfo[pieceStr][endMeasure+1] # ends on downbeat of next measure
            
            tup = (startTime, endTime, startMeasure, endMeasure, startStr, endStr) # startStr more informative than startLine
            d[queryStr].append(tup)
            
    return d

# %%
def saveQueryInfoToFile(d, outfile):
    with open(outfile, 'w') as f:
        for query in sorted(d):
            for (tstart, tend, mstart, mend, lstart, lend) in d[query]:
                f.write('{},{:.2f},{:.2f},{},{},{},{}\n'.format(query, tstart, tend, mstart, mend, lstart, lend))

# %%
queryInfoFile = 'data/query_info/query_info.csv' # to read
multMatchesFile = 'data/query_info/query.multmatches' # to read
queryGTFile = 'data/query_info/query.gt' # to write
queryInfo = getQueryGroundTruth(queryInfoFile, multMatchesFile, scoreInfo, midiInfo)
saveQueryInfoToFile(queryInfo, queryGTFile)

# %% [markdown]
# ### Evaluate system performance

# %%
def readGroundTruthLabels(gtfile):
    d = {}
    with open(gtfile, 'r') as f:
        for line in f:
            parts = line.rstrip().split(',') # e.g. 'p1_q1,1.55,32.59'
            queryStr = parts[0]
            tstart = float(parts[1])
            tend = float(parts[2])
            if queryStr in d:
                d[queryStr].append((tstart, tend))
            else:
                d[queryStr] = [(tstart, tend)]
    return d

# %%
def readHypothesisFiles(hypdir):
    l = []
    for hypfile in sorted(glob.glob("{}/*.hyp".format(hypdir))):
        with open(hypfile, 'r') as f:
            line = next(f)
            parts = line.rstrip().split(',')
            query = parts[0]  # e.g. p1_q1
            tstart = float(parts[1])
            tend = float(parts[2])
            l.append((query, tstart, tend))
    return l

# %%
def calcPrecisionRecall(hypdir, gtfile):
    d = readGroundTruthLabels(gtfile)
    hyps = readHypothesisFiles(hypdir)
    hypinfo = [] 
    overlapTotal, hypTotal, refTotal = (0,0,0)
    for (queryid, hypstart, hypend) in hyps:
        refSegments = d[queryid]
        idxMax = 0
        overlapMax = 0
        for i, refSegment in enumerate(refSegments): # find ref segment with most overlap
            overlap = calcOverlap((hypstart, hypend), refSegment)
            if overlap > overlapMax:
                idxMax = i
                overlapMax = overlap
        hyplen = hypend - hypstart
        reflen = refSegments[idxMax][1] - refSegments[idxMax][0]        
        overlapTotal += overlapMax
        hypTotal += hyplen
        refTotal += reflen
        hypinfo.append((queryid, overlapMax, refSegments[idxMax][0], refSegments[idxMax][1], idxMax)) # keep for error analysis
    P = overlapTotal / hypTotal
    R = overlapTotal / refTotal
    F = 2 * P * R / (P + R)
    return F, P, R, hypinfo

# %%
def calcOverlap(seg1, seg2):
    overlap_lb = max(seg1[0], seg2[0])
    overlap_ub = min(seg1[1], seg2[1])
    overlap = np.clip(overlap_ub - overlap_lb, 0, None)
    return overlap

# %%
hypdir = 'experiments/exp2/hyp'
F, P, R, hypinfo = calcPrecisionRecall(hypdir, queryGTFile)

# %%
F, P, R, len(hypinfo)
# Out:
# (0.8581609057904117, 0.8894500066157977, 0.8289983744189549, 900)

# %% [markdown]
# ### Investigate Errors

# %%
def printDebuggingInfo(hypdir, gtfile, scoreInfo, midiInfo, queryInfo, hypInfo):
    d = readGroundTruthLabels(gtfile)
    hyps = readHypothesisFiles(hypdir)
    for i, (query, hyp_tstart, hyp_tend) in enumerate(hyps):
        
        # hyp and ref info (sec)
        piece = query.split('_')[0]
        _, overlap, ref_tstart, ref_tend, bestIdx = hypInfo[i]
        
        # hyp and ref info (measures)
        interp_m = list(midiInfo[piece].keys())
        interp_t = [midiInfo[piece][m] for m in interp_m]
        hyp_mstart, hyp_mend, ref_mstart, ref_mend = np.interp([hyp_tstart, hyp_tend, ref_tstart, ref_tend], interp_t, interp_m)
        moverlap = calcOverlap((hyp_mstart, hyp_mend),(ref_mstart, ref_mend))
        
        # hyp and ref info (line # + measure offset)
        hyp_lstart, hyp_lstartoff = getLineNumberMeasureOffset(hyp_mstart, scoreInfo[piece])
        hyp_lend, hyp_lendoff = getLineNumberMeasureOffset(hyp_mend, scoreInfo[piece])
        ref_lstart = queryInfo[query][bestIdx][4]
        ref_lend = queryInfo[query][bestIdx][5]
        
        # compare in sec
        print("{}: hyp ({:.1f} s,{:.1f} s), ref ({:.1f} s,{:.1f} s), overlap {:.1f} of {:.1f} s".format(query, hyp_tstart, hyp_tend, ref_tstart, ref_tend, overlap, ref_tend - ref_tstart))
        
        # compare in measure numbers
        #print("\thyp ({:.1f} m, {:.1f} m), ref ({:.1f} m, {:.1f} m), overlap {:.1f} m".format(hyp_mstart, hyp_mend, ref_mstart, ref_mend, moverlap))
        
        # compare in line + measure offset
        print("\thyp (ln {} m{:.1f}, ln {} m{:.1f}), ref (ln {}, ln {})".format(hyp_lstart, hyp_lstartoff, hyp_lend, hyp_lendoff, ref_lstart, ref_lend))
    return

# %%
def getLineNumberMeasureOffset(measureNum, d):
    line = -1
    moffset = -1
    for key in d:
        lb, ub = d[key] # line start, end measure 
        if measureNum >= lb and measureNum < ub + 1:
            line = key
            moffset = measureNum - lb + 1
            break
    return line, moffset

# %%
printDebuggingInfo(hypdir, queryGTFile, scoreInfo, midiInfo, queryInfo, hypinfo)
# Out:
# p100_q1: hyp (192.0 s,226.4 s), ref (193.3 s,227.4 s), overlap 33.2 of 34.1 s
# 	hyp (ln 18 m3.7, ln 21 m3.7), ref (ln 19, ln 21)
# p100_q10: hyp (170.5 s,204.3 s), ref (170.5 s,204.6 s), overlap 33.8 of 34.1 s
# 	hyp (ln 17 m1.0, ln 19 m3.9), ref (ln 17, ln 19)
# p100_q2: hyp (226.9 s,261.0 s), ref (227.4 s,261.5 s), overlap 33.6 of 34.1 s
# 	hyp (ln 21 m3.9, ln 24 m3.9), ref (ln 22, ln 24)
# p100_q3: hyp (261.4 s,283.3 s), ref (261.5 s,291.6 s), overlap 21.8 of 30.1 s
# 	hyp (ln 24 m4.0, ln 27 m1.7), ref (ln 25, ln 27)
# p100_q4: hyp (10.4 s,45.5 s), ref (11.4 s,45.5 s), overlap 34.1 of 34.1 s
# 	hyp (ln 1 m3.7, ln 4 m4.0), ref (ln 2, ln 4)
# p100_q5: hyp (79.3 s,102.0 s), ref (79.6 s,102.3 s), overlap 22.4 of 22.7 s
# 	hyp (ln 7 m3.9, ln 9 m3.9), ref (ln 8, ln 9)
# p100_q6: hyp (0.0 s,33.6 s), ref (0.0 s,34.1 s), overlap 33.6 of 34.1 s
# 	hyp (ln 1 m1.0, ln 3 m3.9), ref (ln 1, ln 3)
# p100_q7: hyp (55.9 s,90.6 s), ref (56.8 s,91.0 s), overlap 33.8 of 34.1 s
# 	hyp (ln 5 m3.7, ln 8 m3.9), ref (ln 6, ln 8)
# p100_q8: hyp (102.0 s,132.3 s), ref (102.3 s,132.6 s), overlap 30.0 of 30.3 s
# 	hyp (ln 9 m3.9, ln 12 m2.9), ref (ln 10, ln 12)
# p100_q9: hyp (132.9 s,158.5 s), ref (132.6 s,159.2 s), overlap 25.6 of 26.5 s
# 	hyp (ln 13 m1.1, ln 15 m3.8), ref (ln 13, ln 15)
# p10_q1: hyp (16.2 s,61.0 s), ref (15.2 s,61.0 s), overlap 44.8 of 45.7 s
# 	hyp (ln 2 m1.2, ln 4 m5.0), ref (ln 2, ln 4)
# p10_q10: hyp (45.7 s,87.6 s), ref (45.7 s,91.4 s), overlap 41.9 of 45.7 s
# 	hyp (ln 3 m5.0, ln 6 m4.0), ref (ln 4, ln 6)
# p10_q2: hyp (30.5 s,76.0 s), ref (30.5 s,76.2 s), overlap 45.5 of 45.7 s
# 	hyp (ln 3 m1.0, ln 5 m4.9), ref (ln 3, ln 5)
# p10_q3: hyp (129.5 s,163.8 s), ref (129.5 s,167.6 s), overlap 34.3 of 38.1 s
# 	hyp (ln 8 m6.0, ln 11 m3.0), ref (ln 9, ln 11)
# p10_q4: hyp (144.6 s,176.8 s), ref (144.8 s,179.1 s), overlap 32.1 of 34.3 s
# 	hyp (ln 9 m5.0, ln 12 m3.4), ref (ln 10, ln 12)
# p10_q5: hyp (110.0 s,155.6 s), ref (110.5 s,156.2 s), overlap 45.1 of 45.7 s
# 	hyp (ln 7 m5.9, ln 10 m3.8), ref (ln 8, ln 10)
# p10_q6: hyp (207.6 s,247.3 s), ref (205.7 s,247.6 s), overlap 39.7 of 41.9 s
# 	hyp (ln 15 m1.5, ln 17 m3.9), ref (ln 15, ln 17)
# p10_q7: hyp (220.9 s,258.8 s), ref (220.9 s,259.1 s), overlap 37.9 of 38.1 s
# 	hyp (ln 15 m5.0, ln 18 m3.9), ref (ln 16, ln 18)
# p10_q8: hyp (236.2 s,276.2 s), ref (236.2 s,278.1 s), overlap 40.0 of 41.9 s
# 	hyp (ln 16 m5.0, ln 19 m5.5), ref (ln 17, ln 19)
# p10_q9: hyp (247.3 s,276.2 s), ref (247.6 s,278.1 s), overlap 28.6 of 30.5 s
# 	hyp (ln 17 m3.9, ln 19 m5.5), ref (ln 18, ln 19)
# p12_q1: hyp (0.8 s,37.9 s), ref (0.0 s,38.2 s), overlap 37.1 of 38.2 s
# 	hyp (ln 1 m1.2, ln 2 m4.9), ref (ln 1, ln 2)
# p12_q10: hyp (139.8 s,171.1 s), ref (139.8 s,173.5 s), overlap 31.3 of 33.8 s
# 	hyp (ln 11 m1.0, ln 12 m5.5), ref (ln 11, ln 12)
# p12_q2: hyp (0.0 s,53.8 s), ref (0.0 s,54.4 s), overlap 53.8 of 54.4 s
# 	hyp (ln 1 m1.0, ln 3 m4.8), ref (ln 1, ln 3)
# p12_q3: hyp (38.2 s,74.1 s), ref (38.2 s,74.4 s), overlap 35.9 of 36.1 s
# 	hyp (ln 3 m1.0, ln 5 m2.9), ref (ln 3, ln 5)
# p12_q4: hyp (54.4 s,84.4 s), ref (54.4 s,86.5 s), overlap 30.0 of 32.1 s
# 	hyp (ln 4 m1.0, ln 6 m3.5), ref (ln 4, ln 6)
# p12_q5: hyp (67.0 s,85.5 s), ref (66.6 s,86.5 s), overlap 18.4 of 20.0 s
# 	hyp (ln 5 m1.1, ln 6 m3.8), ref (ln 5, ln 6)
# p12_q6: hyp (86.5 s,131.7 s), ref (86.5 s,132.0 s), overlap 45.2 of 45.5 s
# 	hyp (ln 7 m1.0, ln 9 m3.9), ref (ln 7, ln 9)
# p12_q7: hyp (108.0 s,143.2 s), ref (108.0 s,139.8 s), overlap 31.8 of 31.8 s
# 	hyp (ln 7 m6.0, ln 11 m1.9), ref (ln 8, ln 10)
# p12_q8: hyp (120.6 s,150.8 s), ref (119.8 s,151.9 s), overlap 30.3 of 32.1 s
# 	hyp (ln 9 m1.2, ln 11 m3.7), ref (ln 9, ln 11)
# p12_q9: hyp (132.2 s,172.0 s), ref (132.0 s,173.5 s), overlap 39.8 of 41.5 s
# 	hyp (ln 10 m1.1, ln 12 m5.7), ref (ln 10, ln 12)
# p13_q1: hyp (0.0 s,31.0 s), ref (0.0 s,31.1 s), overlap 31.0 of 31.1 s
# 	hyp (ln 1 m1.0, ln 3 m7.9), ref (ln 1, ln 3)
# p13_q10: hyp (330.6 s,347.9 s), ref (325.6 s,348.1 s), overlap 17.2 of 22.5 s
# 	hyp (ln 41 m1.5, ln 42 m7.0), ref (ln 40, ln 42)
# p13_q2: hyp (20.4 s,50.0 s), ref (20.5 s,50.1 s), overlap 29.5 of 29.6 s
# 	hyp (ln 2 m7.9, ln 6 m4.9), ref (ln 3, ln 6)
# p13_q3: hyp (45.0 s,60.1 s), ref (44.3 s,60.5 s), overlap 15.1 of 16.2 s
# 	hyp (ln 6 m1.5, ln 7 m7.7), ref (ln 6, ln 7)
# p13_q4: hyp (60.3 s,90.3 s), ref (60.5 s,79.5 s), overlap 19.0 of 19.0 s
# 	hyp (ln 7 m7.9, ln 11 m1.0), ref (ln 8, ln 9)
# p13_q5: hyp (70.5 s,108.5 s), ref (70.7 s,99.4 s), overlap 28.7 of 28.7 s
# 	hyp (ln 8 m7.9, ln 12 m6.7), ref (ln 9, ln 11)
# p13_q6: hyp (90.3 s,129.6 s), ref (90.3 s,119.5 s), overlap 29.2 of 29.2 s
# 	hyp (ln 11 m1.0, ln 14 m7.9), ref (ln 11, ln 13)
# p13_q7: hyp (109.1 s,129.6 s), ref (108.9 s,129.8 s), overlap 20.5 of 20.8 s
# 	hyp (ln 13 m1.1, ln 14 m7.9), ref (ln 13, ln 14)
# p13_q8: hyp (205.3 s,229.7 s), ref (205.4 s,225.9 s), overlap 20.4 of 20.4 s
# 	hyp (ln 22 m5.9, ln 26 m3.6), ref (ln 23, ln 25)
# p13_q9: hyp (279.5 s,295.3 s), ref (279.5 s,302.4 s), overlap 15.8 of 22.9 s
# 	hyp (ln 33 m7.0, ln 35 m4.3), ref (ln 34, ln 35)
# p14_q1: hyp (0.6 s,12.2 s), ref (0.6 s,12.6 s), overlap 11.7 of 12.0 s
# 	hyp (ln 1 m1.0, ln 2 m5.8), ref (ln 1, ln 2)
# p14_q10: hyp (91.3 s,103.3 s), ref (97.9 s,104.2 s), overlap 5.3 of 6.2 s
# 	hyp (ln 14 m5.7, ln 16 m5.0), ref (ln 16, ln 16)
# p14_q2: hyp (6.2 s,24.9 s), ref (12.6 s,25.0 s), overlap 12.3 of 12.5 s
# 	hyp (ln 1 m6.0, ln 4 m5.9), ref (ln 3, ln 4)
# p14_q3: hyp (25.0 s,31.2 s), ref (25.0 s,31.4 s), overlap 6.2 of 6.3 s
# 	hyp (ln 5 m1.0, ln 5 m5.9), ref (ln 5, ln 5)
# p14_q4: hyp (31.4 s,53.1 s), ref (39.5 s,47.0 s), overlap 7.5 of 7.5 s
# 	hyp (ln 5 m6.0, ln 8 m5.9), ref (ln 7, ln 7)
# p14_q5: hyp (62.4 s,76.0 s), ref (59.6 s,72.3 s), overlap 10.0 of 12.7 s
# 	hyp (ln 10 m3.1, ln 12 m3.9), ref (ln 10, ln 11)
# p14_q6: hyp (66.0 s,78.8 s), ref (66.0 s,79.1 s), overlap 12.9 of 13.2 s
# 	hyp (ln 10 m6.0, ln 12 m5.7), ref (ln 11, ln 12)
# p14_q7: hyp (72.3 s,78.8 s), ref (72.3 s,79.1 s), overlap 6.5 of 6.8 s
# 	hyp (ln 12 m1.0, ln 12 m5.7), ref (ln 12, ln 12)
# p14_q8: hyp (79.1 s,91.5 s), ref (79.1 s,85.4 s), overlap 6.2 of 6.2 s
# 	hyp (ln 13 m1.0, ln 14 m5.9), ref (ln 13, ln 13)
# p14_q9: hyp (85.4 s,97.8 s), ref (85.4 s,97.9 s), overlap 12.4 of 12.6 s
# 	hyp (ln 13 m6.0, ln 15 m5.9), ref (ln 14, ln 15)
# p15_q1: hyp (0.0 s,46.2 s), ref (0.0 s,46.5 s), overlap 46.2 of 46.5 s
# 	hyp (ln 1 m1.0, ln 2 m4.0), ref (ln 1, ln 2)
# p15_q10: hyp (348.7 s,379.8 s), ref (348.9 s,379.9 s), overlap 30.9 of 31.0 s
# 	hyp (ln 18 m3.0, ln 20 m3.0), ref (ln 19, ln 20)
# p15_q2: hyp (0.0 s,69.6 s), ref (0.0 s,69.7 s), overlap 69.6 of 69.7 s
# 	hyp (ln 1 m1.0, ln 3 m4.0), ref (ln 1, ln 3)
# p15_q3: hyp (46.3 s,108.2 s), ref (46.5 s,108.4 s), overlap 61.7 of 61.9 s
# 	hyp (ln 2 m4.0, ln 5 m3.0), ref (ln 3, ln 5)
# p15_q4: hyp (92.9 s,122.5 s), ref (92.9 s,123.9 s), overlap 29.6 of 31.0 s
# 	hyp (ln 4 m4.0, ln 6 m2.8), ref (ln 5, ln 6)
# p15_q5: hyp (147.1 s,216.3 s), ref (147.1 s,216.8 s), overlap 69.2 of 69.7 s
# 	hyp (ln 8 m1.0, ln 10 m3.9), ref (ln 8, ln 10)
# p15_q6: hyp (196.0 s,248.1 s), ref (193.6 s,248.3 s), overlap 52.1 of 54.8 s
# 	hyp (ln 10 m1.3, ln 12 m4.0), ref (ln 10, ln 12)
# p15_q7: hyp (248.3 s,286.1 s), ref (248.3 s,287.0 s), overlap 37.7 of 38.7 s
# 	hyp (ln 13 m1.0, ln 14 m2.9), ref (ln 13, ln 14)
# p15_q8: hyp (271.5 s,317.8 s), ref (271.5 s,318.0 s), overlap 46.3 of 46.4 s
# 	hyp (ln 14 m1.0, ln 16 m3.0), ref (ln 14, ln 16)
# p15_q9: hyp (303.0 s,348.5 s), ref (302.5 s,348.9 s), overlap 45.5 of 46.4 s
# 	hyp (ln 16 m1.1, ln 18 m2.9), ref (ln 16, ln 18)
# p16_q1: hyp (82.8 s,110.7 s), ref (91.9 s,116.5 s), overlap 18.8 of 24.5 s
# 	hyp (ln 12 m2.8, ln 15 m4.9), ref (ln L13m4, ln L16m4)
# p16_q10: hyp (122.2 s,149.9 s), ref (131.2 s,150.0 s), overlap 18.7 of 18.8 s
# 	hyp (ln 16 m12.0, ln 20 m7.8), ref (ln 18, ln 20)
# p16_q2: hyp (19.2 s,49.1 s), ref (17.4 s,42.8 s), overlap 23.6 of 25.4 s
# 	hyp (ln 3 m3.2, ln 6 m8.7), ref (ln 3, ln 5)
# p16_q3: hyp (26.7 s,55.0 s), ref (35.5 s,55.9 s), overlap 19.5 of 20.5 s
# 	hyp (ln 4 m1.3, ln 7 m7.8), ref (ln 5, ln 7)
# p16_q4: hyp (81.1 s,103.4 s), ref (81.3 s,107.5 s), overlap 22.1 of 26.2 s
# 	hyp (ln 11 m8.8, ln 14 m7.0), ref (ln 12, ln 14)
# p16_q5: hyp (130.9 s,149.9 s), ref (131.2 s,150.0 s), overlap 18.7 of 18.8 s
# 	hyp (ln 17 m11.7, ln 20 m7.8), ref (ln 18, ln 20)
# p16_q6: hyp (162.9 s,197.1 s), ref (163.1 s,183.6 s), overlap 20.5 of 20.5 s
# 	hyp (ln 22 m9.8, ln 27 m5.5), ref (ln 23, ln 25)
# p16_q7: hyp (193.4 s,211.0 s), ref (193.4 s,210.6 s), overlap 17.2 of 17.2 s
# 	hyp (ln 26 m13.0, ln 29 m1.5), ref (ln 27, ln 28)
# p16_q8: hyp (213.2 s,233.7 s), ref (107.5 s,122.2 s), overlap 0.0 of 14.7 s
# 	hyp (ln 29 m4.3, ln 31 m9.3), ref (ln 15, ln 16)
# p16_q9: hyp (107.3 s,138.4 s), ref (113.2 s,138.6 s), overlap 25.2 of 25.4 s
# 	hyp (ln 14 m11.8, ln 18 m9.8), ref (ln 16, ln 18)
# p17_q1: hyp (0.2 s,20.3 s), ref (0.0 s,20.8 s), overlap 20.1 of 20.8 s
# 	hyp (ln 1 m1.1, ln 2 m4.9), ref (ln 1, ln 2)
# p17_q10: hyp (155.3 s,190.4 s), ref (150.7 s,189.8 s), overlap 34.5 of 39.2 s
# 	hyp (ln 22 m3.2, ln 25 m1.2), ref (ln 22, ln 24)
# p17_q2: hyp (2.2 s,30.8 s), ref (0.0 s,31.1 s), overlap 28.6 of 31.1 s
# 	hyp (ln 1 m1.8, ln 3 m4.9), ref (ln 1, ln 3)
# p17_q3: hyp (20.8 s,50.4 s), ref (20.8 s,50.8 s), overlap 29.6 of 30.1 s
# 	hyp (ln 3 m1.0, ln 5 m4.8), ref (ln 3, ln 5)
# p17_q4: hyp (32.1 s,50.3 s), ref (31.1 s,50.8 s), overlap 18.1 of 19.7 s
# 	hyp (ln 4 m1.5, ln 5 m4.8), ref (ln 4, ln 5)
# p17_q5: hyp (58.3 s,83.0 s), ref (58.5 s,82.5 s), overlap 24.0 of 24.0 s
# 	hyp (ln 6 m4.9, ln 10 m1.2), ref (ln 7, ln 9)
# p17_q6: hyp (175.8 s,184.3 s), ref (73.4 s,94.1 s), overlap 0.0 of 20.7 s
# 	hyp (ln 23 m1.9, ln 24 m2.3), ref (ln 9, ln 10)
# p17_q7: hyp (94.5 s,107.1 s), ref (94.1 s,107.0 s), overlap 12.5 of 12.9 s
# 	hyp (ln 11 m1.2, ln 13 m1.1), ref (ln 11, ln 12)
# p17_q8: hyp (100.4 s,120.4 s), ref (100.2 s,120.3 s), overlap 19.9 of 20.1 s
# 	hyp (ln 12 m1.2, ln 15 m1.1), ref (ln 12, ln 14)
# p17_q9: hyp (127.3 s,138.4 s), ref (125.1 s,138.4 s), overlap 11.1 of 13.3 s
# 	hyp (ln 16 m2.0, ln 18 m4.0), ref (ln 16, ln 18)
# p18_q1: hyp (0.0 s,17.4 s), ref (0.0 s,17.9 s), overlap 17.4 of 17.9 s
# 	hyp (ln 1 m1.0, ln 3 m3.6), ref (ln 1, ln 3)
# p18_q10: hyp (166.3 s,185.0 s), ref (166.4 s,185.3 s), overlap 18.7 of 18.9 s
# 	hyp (ln 27 m3.0, ln 30 m3.9), ref (ln 28, ln 30)
# p18_q2: hyp (6.2 s,24.0 s), ref (6.3 s,24.1 s), overlap 17.7 of 17.9 s
# 	hyp (ln 1 m4.0, ln 4 m3.9), ref (ln 2, ln 4)
# p18_q3: hyp (17.5 s,31.7 s), ref (17.9 s,31.4 s), overlap 13.5 of 13.5 s
# 	hyp (ln 3 m3.7, ln 6 m1.1), ref (ln 4, ln 5)
# p18_q4: hyp (31.1 s,44.0 s), ref (31.4 s,44.1 s), overlap 12.6 of 12.7 s
# 	hyp (ln 5 m4.8, ln 7 m3.9), ref (ln 6, ln 7)
# p18_q5: hyp (44.6 s,60.6 s), ref (44.1 s,60.8 s), overlap 15.9 of 16.8 s
# 	hyp (ln 8 m1.3, ln 10 m3.9), ref (ln 8, ln 10)
# p18_q6: hyp (72.7 s,91.1 s), ref (78.9 s,91.4 s), overlap 12.2 of 12.4 s
# 	hyp (ln 12 m3.0, ln 15 m2.9), ref (ln 14, ln 15)
# p18_q7: hyp (79.2 s,91.1 s), ref (78.9 s,91.4 s), overlap 11.9 of 12.4 s
# 	hyp (ln 14 m1.1, ln 15 m2.9), ref (ln 14, ln 15)
# p18_q8: hyp (91.1 s,109.2 s), ref (91.4 s,110.1 s), overlap 17.8 of 18.7 s
# 	hyp (ln 15 m2.9, ln 18 m2.7), ref (ln 16, ln 18)
# p18_q9: hyp (97.4 s,116.2 s), ref (97.6 s,116.7 s), overlap 18.6 of 19.1 s
# 	hyp (ln 16 m2.9, ln 19 m2.9), ref (ln 17, ln 19)
# p19_q1: hyp (0.9 s,10.5 s), ref (0.9 s,10.6 s), overlap 9.6 of 9.7 s
# 	hyp (ln 1 m1.0, ln 3 m2.9), ref (ln 1, ln 3)
# p19_q10: hyp (11.6 s,17.3 s), ref (48.2 s,67.5 s), overlap 0.0 of 19.2 s
# 	hyp (ln 4 m1.6, ln 5 m2.5), ref (ln 14, ln 15)
# p19_q2: hyp (5.0 s,14.8 s), ref (4.7 s,15.1 s), overlap 9.8 of 10.4 s
# 	hyp (ln 2 m1.2, ln 4 m3.8), ref (ln 2, ln 4)
# p19_q3: hyp (10.6 s,19.4 s), ref (10.6 s,19.6 s), overlap 8.8 of 8.9 s
# 	hyp (ln 3 m3.0, ln 5 m3.9), ref (ln 4, ln 5)
# p19_q4: hyp (19.8 s,27.0 s), ref (19.6 s,26.8 s), overlap 7.0 of 7.3 s
# 	hyp (ln 6 m1.1, ln 8 m1.1), ref (ln 6, ln 7)
# p19_q5: hyp (26.3 s,37.5 s), ref (26.8 s,37.6 s), overlap 10.7 of 10.7 s
# 	hyp (ln 7 m3.6, ln 10 m3.9), ref (ln 8, ln 10)
# p19_q6: hyp (37.9 s,43.8 s), ref (37.6 s,43.5 s), overlap 5.6 of 6.0 s
# 	hyp (ln 11 m1.2, ln 13 m1.2), ref (ln 11, ln 12)
# p19_q7: hyp (37.9 s,48.0 s), ref (37.6 s,48.2 s), overlap 10.2 of 10.6 s
# 	hyp (ln 11 m1.2, ln 13 m3.9), ref (ln 11, ln 13)
# p19_q8: hyp (40.8 s,52.8 s), ref (40.5 s,52.9 s), overlap 12.0 of 12.4 s
# 	hyp (ln 12 m1.2, ln 14 m3.9), ref (ln 12, ln 14)
# p19_q9: hyp (39.1 s,51.5 s), ref (43.5 s,67.5 s), overlap 7.9 of 23.9 s
# 	hyp (ln 11 m2.0, ln 14 m3.1), ref (ln 13, ln 15)
# p20_q1: hyp (0.0 s,20.6 s), ref (0.0 s,20.8 s), overlap 20.6 of 20.8 s
# 	hyp (ln 1 m1.0, ln 2 m3.0), ref (ln 1, ln 2)
# p20_q10: hyp (137.0 s,141.6 s), ref (133.0 s,143.7 s), overlap 4.6 of 10.7 s
# 	hyp (ln 24 m1.1, ln 24 m2.4), ref (ln 23, ln 24)
# p20_q2: hyp (21.8 s,27.3 s), ref (20.8 s,38.0 s), overlap 5.5 of 17.3 s
# 	hyp (ln 3 m1.3, ln 3 m2.7), ref (ln 3, ln 4)
# p20_q3: hyp (47.4 s,58.6 s), ref (47.3 s,61.7 s), overlap 11.2 of 14.4 s
# 	hyp (ln 6 m1.0, ln 8 m2.2), ref (ln 6, ln 8)
# p20_q4: hyp (50.6 s,68.0 s), ref (50.6 s,69.0 s), overlap 17.3 of 18.4 s
# 	hyp (ln 6 m2.0, ln 9 m2.7), ref (ln 7, ln 9)
# p20_q5: hyp (54.5 s,69.2 s), ref (53.8 s,69.0 s), overlap 14.5 of 15.2 s
# 	hyp (ln 8 m1.2, ln 10 m1.1), ref (ln 8, ln 9)
# p20_q6: hyp (70.2 s,85.9 s), ref (73.0 s,86.2 s), overlap 12.9 of 13.1 s
# 	hyp (ln 10 m1.8, ln 12 m3.9), ref (ln 11, ln 12)
# p20_q7: hyp (107.7 s,121.1 s), ref (107.7 s,121.2 s), overlap 13.4 of 13.4 s
# 	hyp (ln 14 m7.0, ln 14 m11.0), ref (ln 17, ln 19)
# p20_q8: hyp (111.8 s,121.0 s), ref (117.3 s,121.2 s), overlap 3.7 of 3.8 s
# 	hyp (ln 14 m8.5, ln 14 m11.0), ref (ln 19, ln 19)
# p20_q9: hyp (72.0 s,87.5 s), ref (125.0 s,136.8 s), overlap 0.0 of 11.8 s
# 	hyp (ln 10 m2.6, ln 13 m1.4), ref (ln 21, ln 23)
# p22_q1: hyp (0.1 s,12.6 s), ref (0.0 s,16.6 s), overlap 12.5 of 16.6 s
# 	hyp (ln 1 m1.1, ln 3 m1.8), ref (ln 1, ln 3)
# p22_q10: hyp (157.8 s,183.7 s), ref (157.8 s,189.8 s), overlap 25.9 of 31.9 s
# 	hyp (ln 21 m4.0, ln 23 m4.3), ref (ln 22, ln 23)
# p22_q2: hyp (11.0 s,26.6 s), ref (11.1 s,27.6 s), overlap 15.5 of 16.5 s
# 	hyp (ln 2 m3.9, ln 5 m3.4), ref (ln 3, ln 5)
# p22_q3: hyp (22.3 s,33.0 s), ref (22.1 s,33.2 s), overlap 10.7 of 11.1 s
# 	hyp (ln 5 m1.1, ln 6 m3.9), ref (ln 5, ln 6)
# p22_q4: hyp (33.0 s,49.7 s), ref (33.2 s,54.4 s), overlap 16.5 of 21.2 s
# 	hyp (ln 6 m3.9, ln 9 m3.9), ref (ln 7, ln 10)
# p22_q5: hyp (44.2 s,67.2 s), ref (44.2 s,59.1 s), overlap 14.9 of 14.9 s
# 	hyp (ln 9 m1.0, ln 12 m2.1), ref (ln 9, ln 11)
# p22_q6: hyp (54.2 s,74.2 s), ref (54.4 s,77.8 s), overlap 19.8 of 23.4 s
# 	hyp (ln 10 m3.9, ln 13 m2.4), ref (ln 11, ln 13)
# p22_q7: hyp (74.2 s,107.3 s), ref (77.8 s,107.8 s), overlap 29.5 of 29.9 s
# 	hyp (ln 13 m2.4, ln 16 m3.9), ref (ln 14, ln 16)
# p22_q8: hyp (97.5 s,125.3 s), ref (97.7 s,127.8 s), overlap 27.5 of 30.0 s
# 	hyp (ln 15 m3.9, ln 18 m3.2), ref (ln 16, ln 18)
# p22_q9: hyp (147.8 s,183.7 s), ref (147.9 s,189.8 s), overlap 35.8 of 41.8 s
# 	hyp (ln 20 m4.0, ln 23 m4.3), ref (ln 21, ln 23)
# p23_q1: hyp (0.0 s,8.2 s), ref (0.0 s,8.3 s), overlap 8.2 of 8.3 s
# 	hyp (ln 1 m1.0, ln 2 m3.9), ref (ln 1, ln 2)
# p23_q10: hyp (157.8 s,168.3 s), ref (151.9 s,173.0 s), overlap 10.5 of 21.1 s
# 	hyp (ln 23 m2.5, ln 24 m4.0), ref (ln 23, ln 24)
# p23_q2: hyp (3.2 s,18.2 s), ref (3.3 s,18.3 s), overlap 14.8 of 14.9 s
# 	hyp (ln 1 m2.9, ln 4 m3.9), ref (ln 2, ln 4)
# p23_q3: hyp (18.2 s,28.1 s), ref (18.3 s,28.2 s), overlap 9.8 of 9.9 s
# 	hyp (ln 4 m3.9, ln 6 m3.9), ref (ln 5, ln 6)
# p23_q4: hyp (28.1 s,38.1 s), ref (28.2 s,38.2 s), overlap 9.8 of 9.9 s
# 	hyp (ln 6 m3.9, ln 8 m3.9), ref (ln 7, ln 8)
# p23_q5: hyp (38.1 s,53.1 s), ref (38.2 s,53.4 s), overlap 14.9 of 15.2 s
# 	hyp (ln 8 m3.9, ln 11 m3.9), ref (ln 9, ln 11)
# p23_q6: hyp (48.1 s,56.3 s), ref (48.1 s,63.8 s), overlap 8.1 of 15.6 s
# 	hyp (ln 11 m1.0, ln 12 m2.1), ref (ln 11, ln 12)
# p23_q7: hyp (71.5 s,99.5 s), ref (71.8 s,99.8 s), overlap 27.8 of 28.0 s
# 	hyp (ln 13 m2.9, ln 16 m2.9), ref (ln 14, ln 16)
# p23_q8: hyp (100.3 s,115.5 s), ref (99.8 s,115.8 s), overlap 15.2 of 16.0 s
# 	hyp (ln 17 m1.1, ln 18 m2.9), ref (ln 17, ln 18)
# p23_q9: hyp (135.8 s,157.7 s), ref (135.8 s,159.9 s), overlap 21.9 of 24.0 s
# 	hyp (ln 20 m3.0, ln 23 m2.5), ref (ln 21, ln 23)
# p24_q1: hyp (0.0 s,14.1 s), ref (0.0 s,14.2 s), overlap 14.1 of 14.2 s
# 	hyp (ln 1 m1.0, ln 2 m8.8), ref (ln 1, ln 2)
# p24_q10: hyp (83.9 s,98.2 s), ref (84.3 s,100.0 s), overlap 13.9 of 15.7 s
# 	hyp (ln 12 m7.6, ln 14 m8.0), ref (ln 13, ln 14)
# p24_q2: hyp (0.0 s,21.2 s), ref (0.0 s,21.8 s), overlap 21.2 of 21.8 s
# 	hyp (ln 1 m1.0, ln 3 m8.3), ref (ln 1, ln 3)
# p24_q3: hyp (6.4 s,28.7 s), ref (6.6 s,29.4 s), overlap 22.1 of 22.7 s
# 	hyp (ln 1 m7.7, ln 4 m8.3), ref (ln 2, ln 4)
# p24_q4: hyp (14.2 s,34.0 s), ref (14.2 s,36.0 s), overlap 19.7 of 21.8 s
# 	hyp (ln 2 m9.0, ln 5 m5.8), ref (ln 3, ln 5)
# p24_q5: hyp (21.9 s,49.3 s), ref (21.8 s,42.6 s), overlap 20.7 of 20.8 s
# 	hyp (ln 4 m1.2, ln 7 m8.0), ref (ln 4, ln 6)
# p24_q6: hyp (35.2 s,49.9 s), ref (36.0 s,50.2 s), overlap 13.9 of 14.2 s
# 	hyp (ln 5 m7.2, ln 7 m8.7), ref (ln 6, ln 7)
# p24_q7: hyp (49.7 s,77.6 s), ref (50.2 s,71.0 s), overlap 20.8 of 20.8 s
# 	hyp (ln 7 m8.4, ln 11 m7.9), ref (ln 8, ln 10)
# p24_q8: hyp (57.3 s,83.4 s), ref (57.8 s,77.7 s), overlap 19.9 of 19.9 s
# 	hyp (ln 8 m8.5, ln 12 m7.0), ref (ln 9, ln 11)
# p24_q9: hyp (70.9 s,95.0 s), ref (71.0 s,91.0 s), overlap 19.9 of 19.9 s
# 	hyp (ln 10 m7.8, ln 14 m5.3), ref (ln 11, ln 13)
# p25_q1: hyp (1.3 s,28.4 s), ref (0.7 s,29.0 s), overlap 27.1 of 28.3 s
# 	hyp (ln 1 m2.0, ln 2 m8.7), ref (ln 1, ln 2)
# p25_q10: hyp (141.7 s,168.2 s), ref (142.0 s,168.4 s), overlap 26.2 of 26.4 s
# 	hyp (ln 10 m7.8, ln 12 m8.0), ref (ln 11, ln 12)
# p25_q2: hyp (0.7 s,58.7 s), ref (0.7 s,44.0 s), overlap 43.3 of 43.3 s
# 	hyp (ln 1 m1.0, ln 4 m8.8), ref (ln 1, ln 3)
# p25_q3: hyp (14.0 s,58.7 s), ref (14.1 s,59.0 s), overlap 44.6 of 44.9 s
# 	hyp (ln 1 m8.9, ln 4 m8.8), ref (ln 2, ln 4)
# p25_q4: hyp (29.0 s,73.2 s), ref (29.0 s,73.5 s), overlap 44.2 of 44.5 s
# 	hyp (ln 3 m1.0, ln 5 m8.8), ref (ln 3, ln 5)
# p25_q5: hyp (44.3 s,73.2 s), ref (44.0 s,73.5 s), overlap 28.8 of 29.4 s
# 	hyp (ln 4 m1.2, ln 5 m8.8), ref (ln 4, ln 5)
# p25_q6: hyp (72.4 s,113.4 s), ref (73.5 s,99.2 s), overlap 25.8 of 25.8 s
# 	hyp (ln 5 m8.4, ln 8 m8.7), ref (ln 6, ln 7)
# p25_q7: hyp (73.2 s,129.6 s), ref (73.5 s,114.1 s), overlap 40.6 of 40.6 s
# 	hyp (ln 5 m8.8, ln 10 m1.3), ref (ln 6, ln 8)
# p25_q8: hyp (98.6 s,149.6 s), ref (99.2 s,142.0 s), overlap 42.8 of 42.8 s
# 	hyp (ln 7 m7.7, ln 11 m5.1), ref (ln 8, ln 10)
# p25_q9: hyp (128.7 s,168.2 s), ref (129.0 s,168.4 s), overlap 39.2 of 39.4 s
# 	hyp (ln 9 m8.8, ln 12 m8.0), ref (ln 10, ln 12)
# p26_q1: hyp (1.5 s,15.5 s), ref (1.5 s,17.2 s), overlap 14.0 of 15.8 s
# 	hyp (ln 1 m1.0, ln 2 m6.0), ref (ln 1, ln 2)
# p26_q10: hyp (133.0 s,146.8 s), ref (125.8 s,141.6 s), overlap 8.6 of 15.8 s
# 	hyp (ln 14 m4.9, ln 16 m4.0), ref (ln 14, ln 15)
# p26_q2: hyp (1.5 s,33.0 s), ref (1.5 s,28.0 s), overlap 26.5 of 26.5 s
# 	hyp (ln 1 m1.0, ln 4 m3.9), ref (ln 1, ln 3)
# p26_q3: hyp (6.7 s,43.7 s), ref (6.8 s,34.8 s), overlap 28.0 of 28.0 s
# 	hyp (ln 1 m5.0, ln 5 m6.0), ref (ln 2, ln 4)
# p26_q4: hyp (15.4 s,55.8 s), ref (17.2 s,58.0 s), overlap 38.5 of 40.7 s
# 	hyp (ln 2 m6.0, ln 5 m12.7), ref (ln 3, ln 6)
# p26_q5: hyp (28.9 s,66.5 s), ref (28.0 s,58.0 s), overlap 29.0 of 30.0 s
# 	hyp (ln 4 m1.6, ln 7 m5.8), ref (ln 4, ln 6)
# p26_q6: hyp (43.5 s,66.5 s), ref (34.8 s,58.0 s), overlap 14.5 of 23.2 s
# 	hyp (ln 5 m5.9, ln 7 m5.8), ref (ln 5, ln 6)
# p26_q7: hyp (75.6 s,111.0 s), ref (68.7 s,97.4 s), overlap 21.8 of 28.7 s
# 	hyp (ln 8 m4.8, ln 12 m2.6), ref (ln 8, ln 10)
# p26_q8: hyp (95.3 s,133.0 s), ref (84.5 s,117.1 s), overlap 21.8 of 32.6 s
# 	hyp (ln 10 m6.9, ln 14 m4.9), ref (ln 10, ln 12)
# p26_q9: hyp (106.0 s,133.0 s), ref (97.4 s,125.8 s), overlap 19.8 of 28.4 s
# 	hyp (ln 11 m5.7, ln 14 m4.9), ref (ln 11, ln 13)
# p27_q1: hyp (1.5 s,27.9 s), ref (1.5 s,28.1 s), overlap 26.4 of 26.6 s
# 	hyp (ln 1 m1.0, ln 2 m5.9), ref (ln 1, ln 2)
# p27_q10: hyp (115.1 s,152.7 s), ref (116.4 s,156.4 s), overlap 36.3 of 40.0 s
# 	hyp (ln 9 m5.5, ln 12 m5.0), ref (ln 10, ln 12)
# p27_q2: hyp (1.5 s,40.9 s), ref (1.5 s,41.3 s), overlap 39.3 of 39.8 s
# 	hyp (ln 1 m1.0, ln 3 m5.8), ref (ln 1, ln 3)
# p27_q3: hyp (27.7 s,66.8 s), ref (28.1 s,67.3 s), overlap 38.7 of 39.1 s
# 	hyp (ln 2 m5.8, ln 5 m5.8), ref (ln 3, ln 5)
# p27_q4: hyp (42.5 s,81.1 s), ref (41.3 s,80.2 s), overlap 37.7 of 38.9 s
# 	hyp (ln 4 m1.5, ln 7 m1.3), ref (ln 4, ln 6)
# p27_q5: hyp (54.5 s,80.2 s), ref (54.6 s,80.2 s), overlap 25.6 of 25.6 s
# 	hyp (ln 4 m5.9, ln 6 m6.0), ref (ln 5, ln 6)
# p27_q6: hyp (79.8 s,101.8 s), ref (80.2 s,103.5 s), overlap 21.5 of 23.2 s
# 	hyp (ln 6 m5.8, ln 8 m4.3), ref (ln 7, ln 8)
# p27_q7: hyp (80.2 s,117.3 s), ref (80.2 s,116.4 s), overlap 36.2 of 36.2 s
# 	hyp (ln 6 m6.0, ln 10 m1.3), ref (ln 7, ln 9)
# p27_q8: hyp (93.2 s,129.1 s), ref (93.3 s,129.6 s), overlap 35.8 of 36.2 s
# 	hyp (ln 7 m6.0, ln 10 m5.8), ref (ln 8, ln 10)
# p27_q9: hyp (102.8 s,142.3 s), ref (103.5 s,142.6 s), overlap 38.8 of 39.1 s
# 	hyp (ln 8 m4.7, ln 11 m5.9), ref (ln 9, ln 11)
# p28_q1: hyp (0.1 s,35.0 s), ref (0.0 s,36.0 s), overlap 34.9 of 36.0 s
# 	hyp (ln 1 m1.0, ln 3 m3.8), ref (ln 1, ln 3)
# p28_q10: hyp (120.5 s,142.0 s), ref (120.0 s,157.0 s), overlap 21.5 of 37.0 s
# 	hyp (ln 11 m1.1, ln 12 m3.5), ref (ln 11, ln 13)
# p28_q2: hyp (89.2 s,94.5 s), ref (12.0 s,48.0 s), overlap 0.0 of 36.0 s
# 	hyp (ln 8 m2.3, ln 8 m3.6), ref (ln 2, ln 4)
# p28_q3: hyp (35.5 s,40.5 s), ref (24.0 s,60.0 s), overlap 5.0 of 36.0 s
# 	hyp (ln 3 m3.9, ln 4 m2.1), ref (ln 3, ln 5)
# p28_q4: hyp (76.5 s,100.2 s), ref (36.0 s,72.0 s), overlap 0.0 of 36.0 s
# 	hyp (ln 7 m2.1, ln 9 m2.1), ref (ln 4, ln 6)
# p28_q5: hyp (93.2 s,121.5 s), ref (72.0 s,108.0 s), overlap 14.8 of 36.0 s
# 	hyp (ln 8 m3.3, ln 11 m1.4), ref (ln 7, ln 9)
# p28_q6: hyp (68.0 s,91.0 s), ref (84.0 s,120.0 s), overlap 7.0 of 36.0 s
# 	hyp (ln 6 m3.0, ln 8 m2.8), ref (ln 8, ln 10)
# p28_q7: hyp (1.5 s,15.5 s), ref (96.0 s,132.0 s), overlap 0.0 of 36.0 s
# 	hyp (ln 1 m1.4, ln 2 m1.9), ref (ln 9, ln 11)
# p28_q8: hyp (113.5 s,132.5 s), ref (108.0 s,144.0 s), overlap 19.0 of 36.0 s
# 	hyp (ln 10 m2.4, ln 12 m1.1), ref (ln 10, ln 12)
# p28_q9: hyp (35.2 s,57.0 s), ref (120.0 s,157.0 s), overlap 0.0 of 37.0 s
# 	hyp (ln 3 m3.8, ln 5 m3.2), ref (ln 11, ln 13)
# p29_q1: hyp (197.5 s,233.1 s), ref (201.9 s,236.2 s), overlap 31.2 of 34.3 s
# 	hyp (ln 11 m7.7, ln 13 m6.0), ref (ln L12m2, ln L13m6)
# p29_q10: hyp (93.6 s,115.8 s), ref (217.6 s,258.5 s), overlap 0.0 of 40.9 s
# 	hyp (ln 6 m4.2, ln 7 m3.9), ref (ln 13, ln 14)
# p29_q2: hyp (0.0 s,48.0 s), ref (0.0 s,49.5 s), overlap 48.0 of 49.5 s
# 	hyp (ln 1 m1.0, ln 3 m5.5), ref (ln 1, ln 3)
# p29_q3: hyp (14.8 s,63.7 s), ref (15.6 s,64.4 s), overlap 48.0 of 48.8 s
# 	hyp (ln 1 m5.8, ln 4 m5.7), ref (ln 2, ln 4)
# p29_q4: hyp (32.7 s,63.7 s), ref (34.3 s,64.4 s), overlap 29.4 of 30.1 s
# 	hyp (ln 2 m6.5, ln 4 m5.7), ref (ln 3, ln 4)
# p29_q5: hyp (140.8 s,198.3 s), ref (84.4 s,138.7 s), overlap 0.0 of 54.3 s
# 	hyp (ln 9 m1.7, ln 12 m1.0), ref (ln 6, ln 8)
# p29_q6: hyp (130.8 s,178.1 s), ref (107.4 s,157.9 s), overlap 27.2 of 50.5 s
# 	hyp (ln 8 m3.2, ln 11 m1.0), ref (ln 7, ln 9)
# p29_q7: hyp (124.4 s,157.9 s), ref (124.4 s,157.9 s), overlap 33.5 of 33.5 s
# 	hyp (ln 8 m1.0, ln 9 m7.0), ref (ln 8, ln 9)
# p29_q8: hyp (178.1 s,234.7 s), ref (178.1 s,236.2 s), overlap 56.6 of 58.2 s
# 	hyp (ln 11 m1.0, ln 13 m6.5), ref (ln 11, ln 13)
# p29_q9: hyp (197.5 s,252.4 s), ref (198.3 s,258.5 s), overlap 54.1 of 60.2 s
# 	hyp (ln 11 m7.7, ln 14 m6.3), ref (ln 12, ln 14)
# p2_q1: hyp (0.0 s,27.0 s), ref (0.0 s,27.4 s), overlap 27.0 of 27.4 s
# 	hyp (ln 1 m1.0, ln 2 m3.9), ref (ln 1, ln 2)
# p2_q10: hyp (108.4 s,141.6 s), ref (108.4 s,144.4 s), overlap 33.2 of 36.0 s
# 	hyp (ln 9 m1.0, ln 11 m2.4), ref (ln 9, ln 11)
# p2_q2: hyp (0.0 s,40.5 s), ref (0.0 s,40.9 s), overlap 40.5 of 40.9 s
# 	hyp (ln 1 m1.0, ln 3 m3.9), ref (ln 1, ln 3)
# p2_q3: hyp (28.5 s,64.1 s), ref (27.4 s,67.9 s), overlap 35.6 of 40.5 s
# 	hyp (ln 3 m1.2, ln 5 m3.2), ref (ln 3, ln 5)
# p2_q4: hyp (54.6 s,81.0 s), ref (54.4 s,81.4 s), overlap 26.4 of 27.0 s
# 	hyp (ln 5 m1.1, ln 6 m3.9), ref (ln 5, ln 6)
# p2_q5: hyp (13.9 s,54.0 s), ref (13.9 s,54.4 s), overlap 40.1 of 40.5 s
# 	hyp (ln 2 m1.0, ln 4 m3.9), ref (ln 2, ln 4)
# p2_q6: hyp (40.9 s,81.0 s), ref (40.9 s,81.4 s), overlap 40.1 of 40.5 s
# 	hyp (ln 4 m1.0, ln 6 m3.9), ref (ln 4, ln 6)
# p2_q7: hyp (81.4 s,108.8 s), ref (81.4 s,108.4 s), overlap 27.0 of 27.0 s
# 	hyp (ln 7 m1.0, ln 9 m1.1), ref (ln 7, ln 8)
# p2_q8: hyp (94.9 s,136.5 s), ref (94.9 s,135.4 s), overlap 40.5 of 40.5 s
# 	hyp (ln 8 m1.0, ln 11 m1.2), ref (ln 8, ln 10)
# p2_q9: hyp (81.4 s,123.2 s), ref (81.4 s,121.9 s), overlap 40.5 of 40.5 s
# 	hyp (ln 7 m1.0, ln 10 m1.3), ref (ln 7, ln 9)
# p30_q1: hyp (0.0 s,12.3 s), ref (0.0 s,12.6 s), overlap 12.3 of 12.6 s
# 	hyp (ln 1 m1.0, ln 2 m5.8), ref (ln 1, ln 2)
# p30_q10: hyp (38.9 s,73.3 s), ref (39.1 s,63.2 s), overlap 24.1 of 24.1 s
# 	hyp (ln 7 m2.8, ln 12 m1.0), ref (ln L7m3, ln L10m5)
# p30_q2: hyp (0.0 s,19.4 s), ref (0.0 s,19.6 s), overlap 19.4 of 19.6 s
# 	hyp (ln 1 m1.0, ln 3 m5.8), ref (ln 1, ln 3)
# p30_q3: hyp (30.8 s,49.0 s), ref (30.8 s,50.5 s), overlap 18.2 of 19.7 s
# 	hyp (ln 6 m1.0, ln 8 m5.0), ref (ln 6, ln 8)
# p30_q4: hyp (36.4 s,54.5 s), ref (36.4 s,56.1 s), overlap 18.1 of 19.7 s
# 	hyp (ln 7 m1.0, ln 9 m3.8), ref (ln 7, ln 9)
# p30_q5: hyp (50.5 s,63.2 s), ref (50.5 s,64.7 s), overlap 12.8 of 14.2 s
# 	hyp (ln 8 m6.0, ln 10 m6.0), ref (ln 9, ln 10)
# p30_q6: hyp (65.0 s,91.0 s), ref (64.7 s,91.0 s), overlap 26.0 of 26.2 s
# 	hyp (ln 11 m1.2, ln 13 m8.0), ref (ln 11, ln 13)
# p30_q7: hyp (81.6 s,107.5 s), ref (81.6 s,108.6 s), overlap 26.0 of 27.0 s
# 	hyp (ln 13 m1.0, ln 15 m5.3), ref (ln 13, ln 15)
# p30_q8: hyp (2.8 s,16.6 s), ref (4.2 s,15.4 s), overlap 11.2 of 11.2 s
# 	hyp (ln 1 m3.0, ln 3 m3.8), ref (ln L1m4, ln L3m2)
# p30_q9: hyp (30.8 s,54.5 s), ref (30.8 s,54.7 s), overlap 23.6 of 23.9 s
# 	hyp (ln 6 m1.0, ln 9 m3.8), ref (ln L6m1, ln L9m3)
# p32_q1: hyp (1.3 s,25.5 s), ref (0.0 s,25.8 s), overlap 24.3 of 25.8 s
# 	hyp (ln 1 m1.5, ln 2 m4.9), ref (ln 1, ln 2)
# p32_q10: hyp (86.6 s,106.1 s), ref (86.6 s,97.2 s), overlap 10.6 of 10.6 s
# 	hyp (ln 9 m1.0, ln 10 m4.5), ref (ln 9, ln 9)
# p32_q2: hyp (0.4 s,35.7 s), ref (0.0 s,35.9 s), overlap 35.3 of 35.9 s
# 	hyp (ln 1 m1.2, ln 3 m4.9), ref (ln 1, ln 3)
# p32_q3: hyp (12.2 s,45.9 s), ref (15.6 s,46.1 s), overlap 30.2 of 30.5 s
# 	hyp (ln 1 m5.7, ln 4 m4.9), ref (ln 2, ln 4)
# p32_q4: hyp (25.6 s,56.0 s), ref (25.8 s,56.3 s), overlap 30.3 of 30.5 s
# 	hyp (ln 2 m5.0, ln 5 m4.9), ref (ln 3, ln 5)
# p32_q5: hyp (36.4 s,56.0 s), ref (35.9 s,56.3 s), overlap 19.7 of 20.3 s
# 	hyp (ln 4 m1.2, ln 5 m4.9), ref (ln 4, ln 5)
# p32_q6: hyp (56.1 s,76.1 s), ref (46.1 s,66.4 s), overlap 10.2 of 20.3 s
# 	hyp (ln 5 m5.0, ln 7 m4.8), ref (ln 5, ln 6)
# p32_q7: hyp (56.3 s,86.6 s), ref (46.1 s,76.5 s), overlap 20.3 of 30.4 s
# 	hyp (ln 6 m1.0, ln 9 m1.0), ref (ln 5, ln 7)
# p32_q8: hyp (66.2 s,95.5 s), ref (56.3 s,86.6 s), overlap 20.4 of 30.3 s
# 	hyp (ln 6 m4.9, ln 9 m4.5), ref (ln 6, ln 8)
# p32_q9: hyp (77.6 s,106.6 s), ref (76.5 s,97.2 s), overlap 19.6 of 20.7 s
# 	hyp (ln 8 m1.4, ln 10 m4.7), ref (ln 8, ln 9)
# p33_q1: hyp (0.0 s,11.7 s), ref (0.0 s,11.8 s), overlap 11.7 of 11.8 s
# 	hyp (ln 1 m1.0, ln 2 m3.9), ref (ln 1, ln 2)
# p33_q10: hyp (41.6 s,54.3 s), ref (48.0 s,58.8 s), overlap 6.2 of 10.7 s
# 	hyp (ln 7 m2.7, ln 9 m4.0), ref (ln 9, ln 10)
# p33_q2: hyp (0.0 s,17.5 s), ref (0.0 s,17.6 s), overlap 17.5 of 17.6 s
# 	hyp (ln 1 m1.0, ln 3 m3.9), ref (ln 1, ln 3)
# p33_q3: hyp (5.5 s,23.7 s), ref (11.8 s,23.7 s), overlap 11.8 of 11.8 s
# 	hyp (ln 1 m3.8, ln 5 m1.0), ref (ln 3, ln 4)
# p33_q4: hyp (18.1 s,29.7 s), ref (11.8 s,29.8 s), overlap 11.6 of 18.0 s
# 	hyp (ln 4 m1.2, ln 5 m3.9), ref (ln 3, ln 5)
# p33_q5: hyp (17.4 s,29.6 s), ref (17.6 s,29.8 s), overlap 11.9 of 12.2 s
# 	hyp (ln 3 m3.9, ln 5 m3.9), ref (ln 4, ln 5)
# p33_q6: hyp (29.6 s,42.0 s), ref (29.8 s,42.1 s), overlap 12.2 of 12.3 s
# 	hyp (ln 5 m3.9, ln 7 m2.9), ref (ln 6, ln 7)
# p33_q7: hyp (29.8 s,48.0 s), ref (38.1 s,48.0 s), overlap 10.0 of 10.0 s
# 	hyp (ln 6 m1.0, ln 9 m1.0), ref (ln 7, ln 8)
# p33_q8: hyp (37.7 s,54.3 s), ref (38.1 s,54.3 s), overlap 16.2 of 16.2 s
# 	hyp (ln 6 m4.8, ln 9 m4.0), ref (ln 7, ln 9)
# p33_q9: hyp (47.9 s,58.3 s), ref (42.1 s,54.3 s), overlap 6.4 of 12.2 s
# 	hyp (ln 8 m3.9, ln 10 m3.0), ref (ln 8, ln 9)
# p34_q1: hyp (87.3 s,113.2 s), ref (0.0 s,29.1 s), overlap 0.0 of 29.1 s
# 	hyp (ln 7 m2.5, ln 9 m2.5), ref (ln 1, ln 2)
# p34_q10: hyp (135.1 s,165.3 s), ref (138.4 s,168.2 s), overlap 26.9 of 29.9 s
# 	hyp (ln 10 m5.7, ln 12 m6.0), ref (ln 11, ln 12)
# p34_q2: hyp (13.2 s,57.4 s), ref (13.2 s,58.1 s), overlap 44.2 of 44.9 s
# 	hyp (ln 2 m1.0, ln 4 m5.7), ref (ln 2, ln 4)
# p34_q3: hyp (39.9 s,70.5 s), ref (44.9 s,70.8 s), overlap 25.5 of 25.9 s
# 	hyp (ln 3 m5.1, ln 5 m5.9), ref (ln 4, ln 5)
# p34_q4: hyp (67.6 s,100.8 s), ref (70.8 s,96.3 s), overlap 25.5 of 25.5 s
# 	hyp (ln 5 m4.7, ln 8 m2.8), ref (ln 6, ln 7)
# p34_q5: hyp (64.5 s,108.3 s), ref (83.4 s,109.3 s), overlap 24.9 of 25.9 s
# 	hyp (ln 5 m3.5, ln 8 m5.6), ref (ln 7, ln 8)
# p34_q6: hyp (94.7 s,122.5 s), ref (96.3 s,122.5 s), overlap 26.3 of 26.3 s
# 	hyp (ln 7 m5.4, ln 10 m1.0), ref (ln 8, ln 9)
# p34_q7: hyp (90.8 s,137.7 s), ref (109.3 s,138.4 s), overlap 28.4 of 29.1 s
# 	hyp (ln 7 m3.9, ln 10 m6.7), ref (ln 9, ln 10)
# p34_q8: hyp (82.2 s,96.9 s), ref (109.3 s,138.4 s), overlap 0.0 of 29.1 s
# 	hyp (ln 6 m5.5, ln 8 m1.3), ref (ln 9, ln 10)
# p34_q9: hyp (133.1 s,166.8 s), ref (138.4 s,168.2 s), overlap 28.4 of 29.9 s
# 	hyp (ln 10 m5.0, ln 12 m6.5), ref (ln 11, ln 12)
# p35_q1: hyp (3.3 s,37.9 s), ref (3.3 s,38.0 s), overlap 34.6 of 34.7 s
# 	hyp (ln 1 m1.0, ln 2 m5.0), ref (ln 1, ln 2)
# p35_q10: hyp (91.5 s,99.1 s), ref (84.9 s,99.1 s), overlap 7.6 of 14.2 s
# 	hyp (ln 9 m2.9, ln 10 m3.0), ref (ln 9, ln 10)
# p35_q2: hyp (3.3 s,46.5 s), ref (3.3 s,49.1 s), overlap 43.2 of 45.8 s
# 	hyp (ln 1 m1.0, ln 3 m3.3), ref (ln 1, ln 3)
# p35_q3: hyp (19.7 s,44.8 s), ref (19.3 s,56.4 s), overlap 25.0 of 37.1 s
# 	hyp (ln 2 m1.1, ln 3 m2.8), ref (ln 2, ln 4)
# p35_q4: hyp (56.7 s,68.7 s), ref (38.0 s,63.7 s), overlap 7.0 of 25.7 s
# 	hyp (ln 5 m1.1, ln 6 m2.4), ref (ln 3, ln 5)
# p35_q5: hyp (43.1 s,44.9 s), ref (49.1 s,63.7 s), overlap 0.0 of 14.6 s
# 	hyp (ln 3 m2.4, ln 3 m2.9), ref (ln 4, ln 5)
# p35_q6: hyp (64.5 s,77.7 s), ref (63.7 s,77.9 s), overlap 13.2 of 14.3 s
# 	hyp (ln 6 m1.2, ln 7 m2.9), ref (ln 6, ln 7)
# p35_q7: hyp (64.3 s,84.8 s), ref (63.7 s,84.9 s), overlap 20.5 of 21.2 s
# 	hyp (ln 6 m1.2, ln 8 m3.0), ref (ln 6, ln 8)
# p35_q8: hyp (70.9 s,91.9 s), ref (70.9 s,91.9 s), overlap 21.0 of 21.0 s
# 	hyp (ln 6 m3.0, ln 10 m1.0), ref (ln 7, ln 9)
# p35_q9: hyp (77.9 s,99.1 s), ref (77.9 s,99.1 s), overlap 21.1 of 21.1 s
# 	hyp (ln 7 m3.0, ln 10 m3.0), ref (ln 8, ln 10)
# p36_q1: hyp (39.9 s,54.1 s), ref (21.5 s,46.9 s), overlap 7.0 of 25.4 s
# 	hyp (ln 4 m3.0, ln 5 m4.2), ref (ln 3, ln 4)
# p36_q10: hyp (238.6 s,288.8 s), ref (242.2 s,294.3 s), overlap 46.6 of 52.2 s
# 	hyp (ln 19 m4.5, ln 22 m7.8), ref (ln 20, ln 22)
# p36_q2: hyp (0.0 s,0.0 s), ref (32.2 s,46.9 s), overlap 0.0 of 14.7 s
# 	hyp (ln 1 m1.0, ln 1 m1.0), ref (ln 4, ln 4)
# p36_q3: hyp (41.6 s,85.0 s), ref (46.9 s,85.3 s), overlap 38.1 of 38.5 s
# 	hyp (ln 4 m3.3, ln 7 m6.8), ref (ln 5, ln 7)
# p36_q4: hyp (70.8 s,108.9 s), ref (71.8 s,110.5 s), overlap 37.2 of 38.8 s
# 	hyp (ln 6 m6.6, ln 9 m5.3), ref (ln 7, ln 9)
# p36_q5: hyp (94.5 s,98.3 s), ref (85.3 s,110.5 s), overlap 3.7 of 25.2 s
# 	hyp (ln 8 m5.0, ln 8 m6.7), ref (ln 8, ln 9)
# p36_q6: hyp (109.3 s,136.8 s), ref (110.5 s,137.2 s), overlap 26.3 of 26.7 s
# 	hyp (ln 9 m5.5, ln 11 m6.8), ref (ln 10, ln 11)
# p36_q7: hyp (122.4 s,163.8 s), ref (123.9 s,164.2 s), overlap 40.0 of 40.3 s
# 	hyp (ln 10 m6.3, ln 13 m6.8), ref (ln 11, ln 13)
# p36_q8: hyp (149.8 s,176.5 s), ref (150.6 s,177.6 s), overlap 25.9 of 27.0 s
# 	hyp (ln 12 m6.7, ln 14 m6.5), ref (ln 13, ln 14)
# p36_q9: hyp (173.2 s,216.6 s), ref (177.6 s,217.7 s), overlap 39.0 of 40.1 s
# 	hyp (ln 14 m5.0, ln 17 m6.5), ref (ln 15, ln 17)
# p37_q1: hyp (0.0 s,14.6 s), ref (0.0 s,14.8 s), overlap 14.6 of 14.8 s
# 	hyp (ln 1 m1.0, ln 2 m7.8), ref (ln 1, ln 2)
# p37_q10: hyp (163.8 s,177.7 s), ref (163.1 s,180.6 s), overlap 13.8 of 17.5 s
# 	hyp (ln 23 m1.7, ln 24 m6.5), ref (ln 23, ln 24)
# p37_q2: hyp (0.0 s,21.6 s), ref (0.0 s,21.7 s), overlap 21.6 of 21.7 s
# 	hyp (ln 1 m1.0, ln 3 m6.8), ref (ln 1, ln 3)
# p37_q3: hyp (6.7 s,28.3 s), ref (6.8 s,28.5 s), overlap 21.6 of 21.8 s
# 	hyp (ln 1 m6.9, ln 4 m6.8), ref (ln 2, ln 4)
# p37_q4: hyp (14.8 s,33.9 s), ref (14.8 s,34.1 s), overlap 19.2 of 19.4 s
# 	hyp (ln 3 m1.0, ln 5 m5.8), ref (ln 3, ln 5)
# p37_q5: hyp (21.7 s,40.3 s), ref (21.7 s,40.8 s), overlap 18.5 of 19.1 s
# 	hyp (ln 3 m7.0, ln 6 m6.5), ref (ln 4, ln 6)
# p37_q6: hyp (28.5 s,40.3 s), ref (28.5 s,40.8 s), overlap 11.8 of 12.3 s
# 	hyp (ln 5 m1.0, ln 6 m6.5), ref (ln 5, ln 6)
# p37_q7: hyp (87.5 s,109.1 s), ref (87.3 s,110.0 s), overlap 21.6 of 22.7 s
# 	hyp (ln 13 m1.2, ln 15 m6.3), ref (ln 13, ln 15)
# p37_q8: hyp (30.2 s,45.7 s), ref (27.4 s,48.7 s), overlap 15.5 of 21.3 s
# 	hyp (ln 5 m2.5, ln 7 m5.3), ref (ln L4m6, ln L7m7)
# p37_q9: hyp (65.6 s,86.7 s), ref (63.4 s,87.3 s), overlap 21.1 of 23.9 s
# 	hyp (ln 10 m2.0, ln 12 m7.5), ref (ln L9m7, ln L12m7)
# p38_q1: hyp (103.8 s,112.3 s), ref (103.9 s,112.5 s), overlap 8.4 of 8.6 s
# 	hyp (ln 22 m5.8, ln 24 m6.7), ref (ln L23m1, ln L24m6)
# p38_q10: hyp (140.0 s,152.8 s), ref (36.1 s,49.0 s), overlap 0.0 of 12.9 s
# 	hyp (ln 31 m6.0, ln 34 m8.0), ref (ln 10, ln 12)
# p38_q2: hyp (0.0 s,11.9 s), ref (0.0 s,12.1 s), overlap 11.9 of 12.1 s
# 	hyp (ln 1 m1.0, ln 3 m5.8), ref (ln 1, ln 3)
# p38_q3: hyp (8.6 s,20.1 s), ref (8.6 s,20.3 s), overlap 11.5 of 11.7 s
# 	hyp (ln 3 m1.0, ln 5 m6.7), ref (ln 3, ln 5)
# p38_q4: hyp (31.1 s,38.0 s), ref (24.5 s,32.7 s), overlap 1.6 of 8.2 s
# 	hyp (ln 8 m4.6, ln 10 m3.8), ref (ln 7, ln 8)
# p38_q5: hyp (28.6 s,39.0 s), ref (28.6 s,39.5 s), overlap 10.3 of 10.9 s
# 	hyp (ln 7 m7.0, ln 10 m5.1), ref (ln 8, ln 10)
# p38_q6: hyp (36.1 s,47.8 s), ref (36.1 s,49.0 s), overlap 11.7 of 12.9 s
# 	hyp (ln 9 m6.0, ln 12 m7.7), ref (ln 10, ln 12)
# p38_q7: hyp (103.6 s,116.2 s), ref (103.9 s,116.0 s), overlap 12.1 of 12.1 s
# 	hyp (ln 22 m5.5, ln 26 m1.3), ref (ln 23, ln 25)
# p38_q8: hyp (12.1 s,24.4 s), ref (12.1 s,24.5 s), overlap 12.3 of 12.4 s
# 	hyp (ln 3 m6.0, ln 6 m6.9), ref (ln L4m1, ln L6m6)
# p38_q9: hyp (28.4 s,40.1 s), ref (28.6 s,40.2 s), overlap 11.5 of 11.6 s
# 	hyp (ln 7 m6.7, ln 11 m1.7), ref (ln L8m1, ln L11m1)
# p39_q1: hyp (0.0 s,22.1 s), ref (0.0 s,22.5 s), overlap 22.1 of 22.5 s
# 	hyp (ln 1 m1.0, ln 2 m6.7), ref (ln 1, ln 2)
# p39_q10: hyp (117.7 s,147.4 s), ref (127.0 s,158.6 s), overlap 20.3 of 31.6 s
# 	hyp (ln 12 m1.5, ln 14 m5.8), ref (ln 13, ln 15)
# p39_q2: hyp (0.0 s,36.5 s), ref (0.0 s,36.8 s), overlap 36.5 of 36.8 s
# 	hyp (ln 1 m1.0, ln 3 m7.8), ref (ln 1, ln 3)
# p39_q3: hyp (62.0 s,75.4 s), ref (62.8 s,75.6 s), overlap 12.7 of 12.8 s
# 	hyp (ln 5 m6.7, ln 7 m6.9), ref (ln 6, ln 7)
# p39_q4: hyp (60.2 s,83.9 s), ref (62.8 s,83.9 s), overlap 21.1 of 21.1 s
# 	hyp (ln 5 m6.1, ln 9 m1.0), ref (ln 6, ln 8)
# p39_q5: hyp (79.1 s,109.5 s), ref (67.5 s,96.9 s), overlap 17.8 of 29.5 s
# 	hyp (ln 8 m3.9, ln 11 m1.7), ref (ln 7, ln 9)
# p39_q6: hyp (84.8 s,107.7 s), ref (83.9 s,108.2 s), overlap 22.9 of 24.4 s
# 	hyp (ln 9 m1.3, ln 10 m6.7), ref (ln 9, ln 10)
# p39_q7: hyp (100.7 s,112.2 s), ref (108.2 s,127.0 s), overlap 4.0 of 18.8 s
# 	hyp (ln 10 m3.0, ln 11 m3.2), ref (ln 11, ln 12)
# p39_q8: hyp (108.0 s,137.9 s), ref (108.2 s,138.4 s), overlap 29.6 of 30.1 s
# 	hyp (ln 10 m6.9, ln 13 m6.7), ref (ln 11, ln 13)
# p39_q9: hyp (29.8 s,61.2 s), ref (116.9 s,147.7 s), overlap 0.0 of 30.8 s
# 	hyp (ln 3 m4.5, ln 5 m6.4), ref (ln 12, ln 14)
# p3_q1: hyp (0.0 s,33.5 s), ref (0.0 s,36.5 s), overlap 33.5 of 36.5 s
# 	hyp (ln 1 m1.0, ln 2 m6.1), ref (ln 1, ln 2)
# p3_q10: hyp (484.6 s,497.4 s), ref (484.6 s,497.6 s), overlap 12.8 of 12.9 s
# 	hyp (ln 56 m5.9, ln 59 m4.9), ref (ln 57, ln 59)
# p3_q2: hyp (52.9 s,98.4 s), ref (52.9 s,98.4 s), overlap 45.6 of 45.6 s
# 	hyp (ln 4 m1.0, ln 6 m6.0), ref (ln 4, ln 6)
# p3_q3: hyp (124.2 s,143.0 s), ref (124.4 s,142.0 s), overlap 17.7 of 17.7 s
# 	hyp (ln 8 m5.9, ln 12 m1.7), ref (ln 9, ln 11)
# p3_q4: hyp (169.0 s,203.2 s), ref (169.4 s,203.4 s), overlap 33.9 of 34.0 s
# 	hyp (ln 15 m5.8, ln 18 m4.9), ref (ln 16, ln 18)
# p3_q5: hyp (203.0 s,220.8 s), ref (203.4 s,220.9 s), overlap 17.3 of 17.5 s
# 	hyp (ln 18 m4.9, ln 20 m3.9), ref (ln 19, ln 20)
# p3_q6: hyp (220.9 s,251.5 s), ref (220.9 s,252.3 s), overlap 30.5 of 31.3 s
# 	hyp (ln 21 m1.0, ln 23 m4.8), ref (ln 21, ln 23)
# p3_q7: hyp (353.3 s,365.0 s), ref (349.3 s,366.0 s), overlap 11.7 of 16.7 s
# 	hyp (ln 40 m4.5, ln 42 m4.4), ref (ln 40, ln 42)
# p3_q8: hyp (366.0 s,389.9 s), ref (366.0 s,390.3 s), overlap 24.0 of 24.3 s
# 	hyp (ln 43 m1.0, ln 45 m4.9), ref (ln 43, ln 45)
# p3_q9: hyp (451.1 s,471.4 s), ref (450.9 s,470.8 s), overlap 19.6 of 19.9 s
# 	hyp (ln 51 m1.1, ln 54 m1.6), ref (ln 51, ln 53)
# p40_q1: hyp (0.0 s,9.8 s), ref (0.0 s,9.8 s), overlap 9.8 of 9.8 s
# 	hyp (ln 1 m1.0, ln 2 m8.0), ref (ln 1, ln 2)
# p40_q10: hyp (44.6 s,53.4 s), ref (43.6 s,54.0 s), overlap 8.8 of 10.4 s
# 	hyp (ln 10 m2.2, ln 11 m6.4), ref (ln 10, ln 11)
# p40_q2: hyp (0.0 s,14.7 s), ref (0.0 s,15.1 s), overlap 14.7 of 15.1 s
# 	hyp (ln 1 m1.0, ln 3 m7.5), ref (ln 1, ln 3)
# p40_q3: hyp (4.3 s,19.5 s), ref (4.5 s,19.6 s), overlap 14.9 of 15.0 s
# 	hyp (ln 1 m6.7, ln 4 m6.8), ref (ln 2, ln 4)
# p40_q4: hyp (11.1 s,24.0 s), ref (9.8 s,24.1 s), overlap 12.9 of 14.3 s
# 	hyp (ln 3 m2.7, ln 5 m6.8), ref (ln 3, ln 5)
# p40_q5: hyp (15.1 s,24.0 s), ref (15.1 s,24.1 s), overlap 8.9 of 9.0 s
# 	hyp (ln 4 m1.0, ln 5 m6.8), ref (ln 4, ln 5)
# p40_q6: hyp (7.6 s,17.3 s), ref (8.3 s,17.4 s), overlap 9.0 of 9.1 s
# 	hyp (ln 2 m5.0, ln 4 m3.8), ref (ln L2m6, ln L4m3)
# p40_q7: hyp (7.6 s,21.7 s), ref (8.3 s,21.8 s), overlap 13.4 of 13.5 s
# 	hyp (ln 2 m5.0, ln 5 m3.8), ref (ln L2m6, ln L5m3)
# p40_q8: hyp (12.1 s,27.0 s), ref (12.1 s,27.1 s), overlap 14.9 of 15.0 s
# 	hyp (ln 3 m4.0, ln 6 m4.8), ref (ln L3m4, ln L6m4)
# p40_q9: hyp (33.9 s,48.4 s), ref (33.9 s,48.9 s), overlap 14.5 of 15.0 s
# 	hyp (ln 8 m1.0, ln 10 m7.3), ref (ln 8, ln 10)
# p42_q1: hyp (42.0 s,60.5 s), ref (0.0 s,21.2 s), overlap 0.0 of 21.2 s
# 	hyp (ln 6 m7.9, ln 9 m5.0), ref (ln 1, ln 3)
# p42_q10: hyp (64.4 s,79.0 s), ref (64.4 s,79.1 s), overlap 14.6 of 14.7 s
# 	hyp (ln 9 m9.0, ln 11 m8.0), ref (ln 10, ln 11)
# p42_q2: hyp (5.6 s,28.9 s), ref (5.8 s,29.0 s), overlap 23.1 of 23.3 s
# 	hyp (ln 1 m6.9, ln 4 m8.9), ref (ln 2, ln 4)
# p42_q3: hyp (12.5 s,28.9 s), ref (12.5 s,29.0 s), overlap 16.4 of 16.6 s
# 	hyp (ln 3 m1.0, ln 4 m8.9), ref (ln 3, ln 4)
# p42_q4: hyp (29.0 s,49.6 s), ref (29.0 s,43.2 s), overlap 14.2 of 14.2 s
# 	hyp (ln 5 m1.0, ln 7 m7.7), ref (ln 5, ln 6)
# p42_q5: hyp (29.3 s,49.8 s), ref (29.0 s,49.9 s), overlap 20.5 of 20.9 s
# 	hyp (ln 5 m1.2, ln 7 m7.9), ref (ln 5, ln 7)
# p42_q6: hyp (34.7 s,56.5 s), ref (34.7 s,56.6 s), overlap 21.8 of 21.9 s
# 	hyp (ln 6 m1.0, ln 8 m7.9), ref (ln 6, ln 8)
# p42_q7: hyp (43.2 s,71.4 s), ref (43.2 s,64.4 s), overlap 21.2 of 21.2 s
# 	hyp (ln 6 m9.0, ln 10 m8.1), ref (ln 7, ln 9)
# p42_q8: hyp (49.8 s,77.0 s), ref (49.9 s,72.2 s), overlap 22.4 of 22.4 s
# 	hyp (ln 7 m7.9, ln 11 m5.9), ref (ln 8, ln 10)
# p42_q9: hyp (56.6 s,78.8 s), ref (56.6 s,79.1 s), overlap 22.2 of 22.5 s
# 	hyp (ln 8 m8.0, ln 11 m7.8), ref (ln 9, ln 11)
# p43_q1: hyp (1.1 s,16.4 s), ref (0.0 s,18.1 s), overlap 15.2 of 18.1 s
# 	hyp (ln 1 m1.8, ln 2 m6.7), ref (ln 1, ln 2)
# p43_q10: hyp (90.6 s,104.7 s), ref (90.6 s,106.7 s), overlap 14.1 of 16.1 s
# 	hyp (ln 12 m1.0, ln 13 m5.6), ref (ln 12, ln 13)
# p43_q2: hyp (0.1 s,26.9 s), ref (0.0 s,27.1 s), overlap 26.8 of 27.1 s
# 	hyp (ln 1 m1.0, ln 3 m7.8), ref (ln 1, ln 3)
# p43_q3: hyp (9.1 s,34.6 s), ref (9.1 s,34.8 s), overlap 25.5 of 25.8 s
# 	hyp (ln 1 m8.0, ln 4 m6.8), ref (ln 2, ln 4)
# p43_q4: hyp (18.1 s,42.3 s), ref (18.1 s,42.5 s), overlap 24.2 of 24.4 s
# 	hyp (ln 3 m1.0, ln 5 m6.8), ref (ln 3, ln 5)
# p43_q5: hyp (50.2 s,79.8 s), ref (50.2 s,75.2 s), overlap 25.0 of 25.0 s
# 	hyp (ln 7 m1.0, ln 10 m4.6), ref (ln 7, ln 9)
# p43_q6: hyp (57.8 s,79.9 s), ref (57.8 s,82.9 s), overlap 22.1 of 25.1 s
# 	hyp (ln 8 m1.0, ln 10 m4.7), ref (ln 8, ln 10)
# p43_q7: hyp (66.1 s,91.0 s), ref (66.1 s,90.6 s), overlap 24.5 of 24.5 s
# 	hyp (ln 8 m7.0, ln 12 m1.3), ref (ln 9, ln 11)
# p43_q8: hyp (75.5 s,97.9 s), ref (75.2 s,98.4 s), overlap 22.4 of 23.2 s
# 	hyp (ln 10 m1.3, ln 12 m6.7), ref (ln 10, ln 12)
# p43_q9: hyp (82.0 s,105.6 s), ref (82.9 s,106.7 s), overlap 22.8 of 23.8 s
# 	hyp (ln 10 m6.3, ln 13 m6.0), ref (ln 11, ln 13)
# p44_q1: hyp (0.6 s,35.7 s), ref (0.0 s,35.7 s), overlap 35.1 of 35.7 s
# 	hyp (ln 1 m1.1, ln 3 m1.0), ref (ln 1, ln 2)
# p44_q10: hyp (230.7 s,264.1 s), ref (231.0 s,271.8 s), overlap 33.1 of 40.8 s
# 	hyp (ln 14 m5.9, ln 17 m2.0), ref (ln 15, ln 17)
# p44_q2: hyp (0.6 s,51.9 s), ref (0.0 s,54.7 s), overlap 51.2 of 54.7 s
# 	hyp (ln 1 m1.1, ln 3 m5.3), ref (ln 1, ln 3)
# p44_q3: hyp (33.7 s,85.4 s), ref (35.7 s,85.4 s), overlap 49.6 of 49.7 s
# 	hyp (ln 2 m5.5, ln 5 m5.0), ref (ln 3, ln 5)
# p44_q4: hyp (68.2 s,101.9 s), ref (54.7 s,104.4 s), overlap 33.7 of 49.7 s
# 	hyp (ln 4 m4.5, ln 6 m5.3), ref (ln 4, ln 6)
# p44_q5: hyp (68.8 s,101.6 s), ref (70.1 s,104.4 s), overlap 31.5 of 34.3 s
# 	hyp (ln 4 m4.7, ln 6 m5.3), ref (ln 5, ln 6)
# p44_q6: hyp (249.4 s,274.8 s), ref (104.4 s,135.8 s), overlap 0.0 of 31.4 s
# 	hyp (ln 16 m1.8, ln 18 m1.8), ref (ln 7, ln 8)
# p44_q7: hyp (136.2 s,176.7 s), ref (135.8 s,177.5 s), overlap 40.6 of 41.7 s
# 	hyp (ln 9 m1.1, ln 11 m3.8), ref (ln 9, ln 11)
# p44_q8: hyp (154.6 s,191.6 s), ref (150.8 s,192.8 s), overlap 37.0 of 42.0 s
# 	hyp (ln 10 m2.0, ln 12 m4.7), ref (ln 10, ln 12)
# p44_q9: hyp (164.4 s,192.7 s), ref (165.8 s,192.8 s), overlap 26.8 of 27.0 s
# 	hyp (ln 10 m4.6, ln 12 m5.0), ref (ln 11, ln 12)
# p45_q1: hyp (0.0 s,15.1 s), ref (0.0 s,15.6 s), overlap 15.1 of 15.6 s
# 	hyp (ln 1 m1.0, ln 2 m4.7), ref (ln 1, ln 2)
# p45_q10: hyp (106.0 s,116.8 s), ref (100.7 s,112.5 s), overlap 6.5 of 11.9 s
# 	hyp (ln 15 m3.8, ln 17 m2.7), ref (ln 15, ln 16)
# p45_q2: hyp (0.0 s,23.2 s), ref (0.0 s,23.5 s), overlap 23.2 of 23.5 s
# 	hyp (ln 1 m1.0, ln 3 m4.8), ref (ln 1, ln 3)
# p45_q3: hyp (9.1 s,15.3 s), ref (7.7 s,31.3 s), overlap 6.2 of 23.5 s
# 	hyp (ln 2 m1.7, ln 2 m4.9), ref (ln 2, ln 4)
# p45_q4: hyp (31.3 s,46.0 s), ref (31.3 s,47.0 s), overlap 14.8 of 15.8 s
# 	hyp (ln 4 m5.0, ln 6 m4.5), ref (ln 5, ln 6)
# p45_q5: hyp (53.6 s,61.6 s), ref (39.1 s,54.9 s), overlap 1.3 of 15.7 s
# 	hyp (ln 8 m4.3, ln 9 m4.4), ref (ln 6, ln 8)
# p45_q6: hyp (76.2 s,84.1 s), ref (54.9 s,76.7 s), overlap 0.5 of 21.8 s
# 	hyp (ln 11 m3.7, ln 12 m4.7), ref (ln 9, ln 11)
# p45_q7: hyp (99.6 s,107.5 s), ref (62.7 s,84.8 s), overlap 0.0 of 22.1 s
# 	hyp (ln 14 m4.5, ln 16 m1.6), ref (ln 10, ln 12)
# p45_q8: hyp (76.7 s,84.1 s), ref (70.7 s,84.8 s), overlap 7.4 of 14.1 s
# 	hyp (ln 11 m4.0, ln 12 m4.7), ref (ln 11, ln 12)
# p45_q9: hyp (56.8 s,59.7 s), ref (84.8 s,100.7 s), overlap 0.0 of 15.9 s
# 	hyp (ln 9 m2.0, ln 9 m3.5), ref (ln 13, ln 14)
# p46_q1: hyp (4.8 s,22.4 s), ref (4.8 s,24.0 s), overlap 17.7 of 19.3 s
# 	hyp (ln 1 m4.0, ln 4 m4.0), ref (ln 2, ln 4)
# p46_q10: hyp (161.0 s,180.5 s), ref (161.0 s,180.7 s), overlap 19.5 of 19.7 s
# 	hyp (ln 25 m6.0, ln 28 m4.9), ref (ln 26, ln 28)
# p46_q2: hyp (34.0 s,42.3 s), ref (17.6 s,30.4 s), overlap 0.0 of 12.8 s
# 	hyp (ln 6 m3.2, ln 7 m4.4), ref (ln 4, ln 5)
# p46_q3: hyp (30.6 s,48.8 s), ref (30.4 s,49.6 s), overlap 18.2 of 19.2 s
# 	hyp (ln 6 m1.1, ln 8 m4.5), ref (ln 6, ln 8)
# p46_q4: hyp (43.4 s,61.9 s), ref (43.2 s,62.5 s), overlap 18.5 of 19.2 s
# 	hyp (ln 8 m1.1, ln 10 m4.7), ref (ln 8, ln 10)
# p46_q5: hyp (55.9 s,68.7 s), ref (56.0 s,68.9 s), overlap 12.7 of 12.9 s
# 	hyp (ln 9 m4.9, ln 11 m4.8), ref (ln 10, ln 11)
# p46_q6: hyp (69.2 s,88.2 s), ref (68.9 s,88.4 s), overlap 18.9 of 19.5 s
# 	hyp (ln 12 m1.2, ln 14 m4.8), ref (ln 12, ln 14)
# p46_q7: hyp (11.3 s,29.9 s), ref (11.2 s,30.4 s), overlap 18.5 of 19.2 s
# 	hyp (ln 3 m1.1, ln 5 m4.7), ref (ln L3m1, ln L5m4)
# p46_q8: hyp (18.3 s,36.0 s), ref (17.6 s,36.8 s), overlap 17.7 of 19.2 s
# 	hyp (ln 4 m1.4, ln 6 m4.5), ref (ln L4m1, ln L6m4)
# p46_q9: hyp (36.8 s,57.3 s), ref (36.8 s,57.6 s), overlap 20.5 of 20.8 s
# 	hyp (ln 7 m1.0, ln 10 m1.8), ref (ln L7m1, ln L10m1)
# p47_q1: hyp (0.1 s,10.2 s), ref (0.0 s,11.2 s), overlap 10.1 of 11.2 s
# 	hyp (ln 1 m1.1, ln 2 m6.0), ref (ln 1, ln 2)
# p47_q10: hyp (99.1 s,115.9 s), ref (99.3 s,122.6 s), overlap 16.5 of 23.3 s
# 	hyp (ln 16 m6.7, ln 19 m4.0), ref (ln 17, ln 19)
# p47_q2: hyp (0.8 s,16.0 s), ref (0.0 s,16.2 s), overlap 15.2 of 16.2 s
# 	hyp (ln 1 m1.7, ln 3 m5.7), ref (ln 1, ln 3)
# p47_q3: hyp (5.4 s,21.4 s), ref (11.2 s,22.4 s), overlap 10.1 of 11.2 s
# 	hyp (ln 2 m1.3, ln 4 m6.0), ref (ln 3, ln 4)
# p47_q4: hyp (11.9 s,22.2 s), ref (16.2 s,22.4 s), overlap 5.9 of 6.2 s
# 	hyp (ln 3 m1.6, ln 4 m6.8), ref (ln 4, ln 4)
# p47_q5: hyp (22.4 s,41.4 s), ref (22.4 s,41.6 s), overlap 18.9 of 19.2 s
# 	hyp (ln 5 m1.0, ln 7 m6.8), ref (ln 5, ln 7)
# p47_q6: hyp (35.5 s,54.1 s), ref (35.5 s,54.8 s), overlap 18.6 of 19.2 s
# 	hyp (ln 6 m7.0, ln 9 m7.4), ref (ln 7, ln 9)
# p47_q7: hyp (41.6 s,54.0 s), ref (41.6 s,54.8 s), overlap 12.3 of 13.1 s
# 	hyp (ln 8 m1.0, ln 9 m7.2), ref (ln 8, ln 9)
# p47_q8: hyp (66.7 s,86.9 s), ref (66.7 s,87.2 s), overlap 20.2 of 20.5 s
# 	hyp (ln 11 m7.0, ln 14 m6.7), ref (ln 12, ln 14)
# p47_q9: hyp (87.4 s,104.9 s), ref (87.2 s,105.4 s), overlap 17.5 of 18.3 s
# 	hyp (ln 15 m1.3, ln 17 m6.5), ref (ln 15, ln 17)
# p48_q1: hyp (0.0 s,18.5 s), ref (0.0 s,18.6 s), overlap 18.5 of 18.6 s
# 	hyp (ln 1 m1.0, ln 3 m4.9), ref (ln 1, ln 3)
# p48_q10: hyp (224.4 s,245.2 s), ref (217.6 s,237.7 s), overlap 13.2 of 20.1 s
# 	hyp (ln 34 m1.0, ln 36 m5.6), ref (ln 33, ln 35)
# p48_q2: hyp (5.2 s,25.2 s), ref (4.9 s,25.3 s), overlap 20.0 of 20.4 s
# 	hyp (ln 2 m1.2, ln 4 m4.9), ref (ln 2, ln 4)
# p48_q3: hyp (25.3 s,44.8 s), ref (25.3 s,44.9 s), overlap 19.5 of 19.6 s
# 	hyp (ln 4 m5.0, ln 7 m4.9), ref (ln 5, ln 7)
# p48_q4: hyp (38.3 s,58.5 s), ref (38.3 s,58.7 s), overlap 20.2 of 20.3 s
# 	hyp (ln 6 m5.0, ln 9 m4.9), ref (ln 7, ln 9)
# p48_q5: hyp (44.9 s,58.7 s), ref (44.9 s,58.7 s), overlap 13.7 of 13.7 s
# 	hyp (ln 7 m5.0, ln 10 m1.0), ref (ln 8, ln 9)
# p48_q6: hyp (70.5 s,87.3 s), ref (70.5 s,87.4 s), overlap 16.8 of 17.0 s
# 	hyp (ln 12 m1.0, ln 14 m3.9), ref (ln 12, ln 14)
# p48_q7: hyp (203.9 s,209.1 s), ref (77.3 s,87.4 s), overlap 0.0 of 10.2 s
# 	hyp (ln 30 m4.8, ln 31 m4.0), ref (ln 13, ln 14)
# p48_q8: hyp (5.2 s,25.2 s), ref (4.9 s,25.3 s), overlap 20.0 of 20.4 s
# 	hyp (ln 2 m1.2, ln 4 m4.9), ref (ln L2m1, ln L4m4)
# p48_q9: hyp (229.2 s,245.8 s), ref (101.1 s,114.5 s), overlap 0.0 of 13.4 s
# 	hyp (ln 34 m3.8, ln 36 m6.0), ref (ln 17, ln 18)
# p49_q1: hyp (7.0 s,37.7 s), ref (0.0 s,38.4 s), overlap 30.7 of 38.4 s
# 	hyp (ln 1 m2.7, ln 2 m4.9), ref (ln 1, ln 2)
# p49_q10: hyp (212.6 s,248.0 s), ref (216.1 s,249.2 s), overlap 31.9 of 33.1 s
# 	hyp (ln 13 m4.0, ln 15 m3.8), ref (ln 14, ln 15)
# p49_q2: hyp (7.0 s,57.9 s), ref (0.0 s,55.1 s), overlap 48.1 of 55.1 s
# 	hyp (ln 1 m2.7, ln 4 m1.7), ref (ln 1, ln 3)
# p49_q3: hyp (66.3 s,87.9 s), ref (55.1 s,90.7 s), overlap 21.6 of 35.6 s
# 	hyp (ln 4 m3.2, ln 5 m4.3), ref (ln 4, ln 5)
# p49_q4: hyp (183.3 s,200.8 s), ref (90.7 s,125.2 s), overlap 0.0 of 34.5 s
# 	hyp (ln 11 m4.4, ln -1 m-1.0), ref (ln 6, ln 7)
# p49_q5: hyp (106.0 s,152.2 s), ref (107.4 s,155.4 s), overlap 44.8 of 48.0 s
# 	hyp (ln 6 m4.6, ln 9 m4.0), ref (ln 7, ln 9)
# p49_q6: hyp (134.2 s,158.0 s), ref (140.4 s,166.4 s), overlap 17.6 of 26.0 s
# 	hyp (ln 8 m3.2, ln 10 m1.8), ref (ln 9, ln 10)
# p49_q7: hyp (165.0 s,200.1 s), ref (166.4 s,238.4 s), overlap 33.7 of 72.0 s
# 	hyp (ln 10 m4.3, ln -1 m-1.0), ref (ln 11, ln 12)
# p49_q8: hyp (165.0 s,214.7 s), ref (166.4 s,216.1 s), overlap 48.3 of 49.7 s
# 	hyp (ln 10 m4.3, ln 13 m4.6), ref (ln 11, ln 13)
# p49_q9: hyp (188.2 s,230.7 s), ref (223.1 s,232.1 s), overlap 7.7 of 9.1 s
# 	hyp (ln -1 m-1.0, ln 12 m3.5), ref (ln 12, ln 14)
# p4_q1: hyp (9.4 s,25.9 s), ref (9.4 s,24.4 s), overlap 15.1 of 15.1 s
# 	hyp (ln 2 m4.0, ln 6 m1.8), ref (ln 3, ln 5)
# p4_q10: hyp (123.0 s,138.3 s), ref (123.0 s,138.6 s), overlap 15.3 of 15.5 s
# 	hyp (ln 26 m1.0, ln 28 m4.7), ref (ln 26, ln 28)
# p4_q2: hyp (19.3 s,24.2 s), ref (19.3 s,29.5 s), overlap 4.9 of 10.2 s
# 	hyp (ln 4 m4.0, ln 5 m3.9), ref (ln 5, ln 6)
# p4_q3: hyp (17.5 s,22.6 s), ref (34.4 s,49.3 s), overlap 0.0 of 14.9 s
# 	hyp (ln 4 m3.0, ln 5 m2.9), ref (ln 8, ln 10)
# p4_q4: hyp (0.0 s,0.0 s), ref (44.5 s,54.2 s), overlap 0.0 of 9.7 s
# ...
# 	hyp (ln 1 m2.0, ln 3 m4.9), ref (ln 1, ln 3)
# p88_q10: hyp (36.3 s,89.9 s), ref (36.6 s,92.2 s), overlap 53.3 of 55.6 s
# 	hyp (ln 2 m4.9, ln 5 m4.7), ref (ln 3, ln 5)
# p88_q2: hyp (112.5 s,160.7 s), ref (113.4 s,161.6 s), overlap 47.2 of 48.1 s
# 	hyp (ln 6 m4.8, ln 9 m3.8), ref (ln 7, ln 9)
# p88_q3: hyp (127.5 s,182.6 s), ref (129.3 s,182.9 s), overlap 53.4 of 53.6 s
# 	hyp (ln 7 m3.7, ln 10 m5.0), ref (ln 8, ln 10)
# p88_q4: hyp (177.5 s,229.0 s), ref (182.9 s,229.3 s), overlap 46.1 of 46.5 s
# 	hyp (ln 10 m4.0, ln 13 m4.9), ref (ln 11, ln 13)
# p88_q5: hyp (211.1 s,271.4 s), ref (212.2 s,275.3 s), overlap 59.2 of 63.0 s
# 	hyp (ln 12 m3.7, ln 15 m5.0), ref (ln 13, ln 15)
# p88_q6: hyp (35.6 s,91.0 s), ref (36.6 s,92.2 s), overlap 54.4 of 55.6 s
# 	hyp (ln 2 m4.8, ln 5 m4.8), ref (ln 3, ln 5)
# p88_q7: hyp (89.9 s,144.8 s), ref (92.2 s,145.6 s), overlap 52.6 of 53.4 s
# 	hyp (ln 5 m4.7, ln 8 m3.8), ref (ln 6, ln 8)
# p88_q8: hyp (197.5 s,245.4 s), ref (199.6 s,245.8 s), overlap 45.9 of 46.2 s
# 	hyp (ln 11 m4.5, ln 14 m4.9), ref (ln 12, ln 14)
# p88_q9: hyp (16.6 s,70.5 s), ref (19.4 s,70.5 s), overlap 51.0 of 51.0 s
# 	hyp (ln 1 m5.3, ln 5 m1.0), ref (ln 2, ln 4)
# p89_q1: hyp (6.6 s,24.7 s), ref (6.2 s,25.0 s), overlap 18.1 of 18.8 s
# 	hyp (ln 2 m1.2, ln 4 m5.8), ref (ln 2, ln 4)
# p89_q10: hyp (18.4 s,31.1 s), ref (18.8 s,31.2 s), overlap 12.3 of 12.5 s
# 	hyp (ln 3 m5.8, ln 5 m5.9), ref (ln 4, ln 5)
# p89_q2: hyp (31.2 s,49.8 s), ref (31.2 s,50.0 s), overlap 18.6 of 18.8 s
# 	hyp (ln 6 m1.0, ln 8 m5.9), ref (ln 6, ln 8)
# p89_q3: hyp (43.4 s,62.0 s), ref (43.8 s,62.5 s), overlap 18.3 of 18.8 s
# 	hyp (ln 7 m5.8, ln 10 m5.6), ref (ln 8, ln 10)
# p89_q4: hyp (62.5 s,82.2 s), ref (62.5 s,82.5 s), overlap 19.7 of 20.0 s
# 	hyp (ln 10 m6.0, ln 13 m6.8), ref (ln 11, ln 13)
# p89_q5: hyp (74.7 s,95.9 s), ref (75.0 s,97.4 s), overlap 20.9 of 22.4 s
# 	hyp (ln 12 m5.8, ln 15 m5.8), ref (ln 13, ln 15)
# p89_q6: hyp (0.0 s,12.2 s), ref (0.0 s,12.5 s), overlap 12.2 of 12.5 s
# 	hyp (ln 1 m1.0, ln 2 m5.8), ref (ln 1, ln 2)
# p89_q7: hyp (12.5 s,31.1 s), ref (12.5 s,31.2 s), overlap 18.6 of 18.8 s
# 	hyp (ln 3 m1.0, ln 5 m5.9), ref (ln 3, ln 5)
# p89_q8: hyp (37.5 s,55.9 s), ref (37.5 s,56.2 s), overlap 18.4 of 18.8 s
# 	hyp (ln 7 m1.0, ln 9 m5.8), ref (ln 7, ln 9)
# p89_q9: hyp (68.8 s,89.7 s), ref (68.8 s,90.0 s), overlap 20.9 of 21.2 s
# 	hyp (ln 12 m1.0, ln 14 m6.8), ref (ln 12, ln 14)
# p8_q1: hyp (0.0 s,24.5 s), ref (0.0 s,24.9 s), overlap 24.5 of 24.9 s
# 	hyp (ln 1 m1.0, ln 3 m2.9), ref (ln 1, ln 3)
# p8_q10: hyp (93.9 s,103.1 s), ref (199.3 s,218.3 s), overlap 0.0 of 19.0 s
# 	hyp (ln 17 m2.0, ln 19 m1.4), ref (ln 37, ln 38)
# p8_q2: hyp (16.7 s,40.8 s), ref (16.7 s,41.4 s), overlap 24.0 of 24.7 s
# 	hyp (ln 2 m3.0, ln 5 m2.8), ref (ln 3, ln 5)
# p8_q3: hyp (50.4 s,62.6 s), ref (49.8 s,62.1 s), overlap 11.7 of 12.3 s
# 	hyp (ln 7 m1.1, ln 10 m1.1), ref (ln 7, ln 9)
# p8_q4: hyp (67.0 s,80.5 s), ref (66.2 s,78.5 s), overlap 11.4 of 12.3 s
# 	hyp (ln 11 m1.2, ln 14 m1.5), ref (ln 11, ln 13)
# p8_q5: hyp (71.1 s,83.1 s), ref (70.3 s,82.6 s), overlap 11.5 of 12.3 s
# 	hyp (ln 12 m1.2, ln 15 m1.1), ref (ln 12, ln 14)
# p8_q6: hyp (122.4 s,135.8 s), ref (119.1 s,131.1 s), overlap 8.7 of 12.0 s
# 	hyp (ln 23 m1.8, ln 27 m1.2), ref (ln 23, ln 25)
# p8_q7: hyp (135.8 s,148.4 s), ref (131.1 s,143.1 s), overlap 7.2 of 12.0 s
# 	hyp (ln 27 m1.2, ln 29 m2.3), ref (ln 26, ln 28)
# p8_q8: hyp (167.9 s,183.9 s), ref (159.1 s,175.1 s), overlap 7.1 of 16.0 s
# 	hyp (ln 32 m1.2, ln 35 m1.1), ref (ln 31, ln 33)
# p8_q9: hyp (174.0 s,187.7 s), ref (167.1 s,183.3 s), overlap 9.3 of 16.2 s
# 	hyp (ln 33 m1.7, ln 35 m2.1), ref (ln 32, ln 34)
# p90_q1: hyp (0.0 s,61.3 s), ref (0.0 s,62.5 s), overlap 61.3 of 62.5 s
# 	hyp (ln 1 m1.0, ln 3 m8.5), ref (ln 1, ln 3)
# p90_q10: hyp (102.5 s,132.3 s), ref (102.5 s,132.5 s), overlap 29.8 of 30.0 s
# 	hyp (ln 6 m1.0, ln 8 m4.9), ref (ln 6, ln 8)
# p90_q2: hyp (42.5 s,102.3 s), ref (42.5 s,102.5 s), overlap 59.8 of 60.0 s
# 	hyp (ln 3 m1.0, ln 5 m6.9), ref (ln 3, ln 5)
# p90_q3: hyp (102.5 s,131.9 s), ref (112.5 s,142.5 s), overlap 19.4 of 30.0 s
# 	hyp (ln 6 m1.0, ln 8 m4.8), ref (ln 7, ln 9)
# p90_q4: hyp (162.5 s,191.9 s), ref (162.5 s,192.5 s), overlap 29.4 of 30.0 s
# 	hyp (ln 12 m1.0, ln 14 m4.8), ref (ln 12, ln 14)
# p90_q5: hyp (192.5 s,239.4 s), ref (192.5 s,245.0 s), overlap 46.9 of 52.5 s
# 	hyp (ln 15 m1.0, ln 17 m5.8), ref (ln 15, ln 17)
# p90_q6: hyp (21.8 s,84.4 s), ref (20.0 s,87.5 s), overlap 62.5 of 67.5 s
# 	hyp (ln 2 m1.7, ln 4 m9.8), ref (ln 2, ln 4)
# p90_q7: hyp (132.5 s,162.3 s), ref (132.5 s,162.5 s), overlap 29.8 of 30.0 s
# 	hyp (ln 9 m1.0, ln 11 m4.9), ref (ln 9, ln 11)
# p90_q8: hyp (172.5 s,209.4 s), ref (172.5 s,210.0 s), overlap 36.9 of 37.5 s
# 	hyp (ln 13 m1.0, ln 15 m7.8), ref (ln 13, ln 15)
# p90_q9: hyp (182.5 s,227.5 s), ref (182.5 s,227.5 s), overlap 45.0 of 45.0 s
# 	hyp (ln 14 m1.0, ln 17 m1.0), ref (ln 14, ln 16)
# p92_q1: hyp (21.7 s,49.1 s), ref (30.0 s,49.3 s), overlap 19.1 of 19.3 s
# 	hyp (ln 3 m1.1, ln 6 m3.9), ref (ln 4, ln 6)
# p92_q10: hyp (194.7 s,214.2 s), ref (195.0 s,214.3 s), overlap 19.2 of 19.3 s
# 	hyp (ln 25 m3.9, ln 28 m3.9), ref (ln 26, ln 28)
# p92_q2: hyp (68.3 s,96.2 s), ref (68.6 s,96.4 s), overlap 27.6 of 27.9 s
# 	hyp (ln 9 m3.9, ln 12 m5.9), ref (ln 10, ln 12)
# p92_q3: hyp (106.1 s,132.6 s), ref (107.1 s,132.9 s), overlap 25.5 of 25.7 s
# 	hyp (ln 13 m5.5, ln 16 m3.9), ref (ln 14, ln 16)
# p92_q4: hyp (133.9 s,156.2 s), ref (132.9 s,156.4 s), overlap 22.3 of 23.6 s
# 	hyp (ln 17 m1.5, ln 19 m3.9), ref (ln 17, ln 19)
# p92_q5: hyp (207.5 s,226.7 s), ref (207.9 s,227.1 s), overlap 18.9 of 19.3 s
# 	hyp (ln 27 m3.8, ln 30 m3.8), ref (ln 28, ln 30)
# p92_q6: hyp (49.2 s,68.4 s), ref (49.3 s,68.6 s), overlap 19.1 of 19.3 s
# 	hyp (ln 6 m4.0, ln 9 m3.9), ref (ln 7, ln 9)
# p92_q7: hyp (133.9 s,156.3 s), ref (132.9 s,156.4 s), overlap 22.4 of 23.6 s
# 	hyp (ln 17 m1.5, ln 19 m3.9), ref (ln 17, ln 19)
# p92_q8: hyp (156.2 s,175.6 s), ref (156.4 s,175.7 s), overlap 19.2 of 19.3 s
# 	hyp (ln 19 m3.9, ln 22 m3.9), ref (ln 20, ln 22)
# p92_q9: hyp (175.3 s,194.9 s), ref (175.7 s,195.0 s), overlap 19.2 of 19.3 s
# 	hyp (ln 22 m3.8, ln 25 m3.9), ref (ln 23, ln 25)
# p93_q1: hyp (0.0 s,22.5 s), ref (0.0 s,22.6 s), overlap 22.5 of 22.6 s
# 	hyp (ln 1 m1.0, ln 3 m3.9), ref (ln 1, ln 3)
# p93_q10: hyp (213.5 s,237.1 s), ref (213.5 s,237.8 s), overlap 23.5 of 24.2 s
# 	hyp (ln 27 m1.0, ln 29 m5.0), ref (ln 27, ln 29)
# p93_q2: hyp (29.4 s,55.2 s), ref (30.1 s,55.9 s), overlap 25.1 of 25.8 s
# 	hyp (ln 4 m3.7, ln 7 m3.8), ref (ln 5, ln 7)
# p93_q3: hyp (49.1 s,75.0 s), ref (55.9 s,75.2 s), overlap 19.1 of 19.3 s
# 	hyp (ln 7 m1.8, ln 9 m3.9), ref (ln 8, ln 9)
# p93_q4: hyp (75.3 s,93.0 s), ref (75.2 s,93.5 s), overlap 17.7 of 18.3 s
# 	hyp (ln 10 m1.0, ln 12 m2.8), ref (ln 10, ln 12)
# p93_q5: hyp (198.4 s,218.6 s), ref (200.1 s,220.4 s), overlap 18.5 of 20.2 s
# 	hyp (ln 24 m3.4, ln 27 m3.3), ref (ln 25, ln 27)
# p93_q6: hyp (87.9 s,105.3 s), ref (87.5 s,105.7 s), overlap 17.4 of 18.2 s
# 	hyp (ln 12 m1.2, ln 14 m2.9), ref (ln 12, ln 14)
# p93_q7: hyp (115.4 s,147.0 s), ref (115.4 s,147.4 s), overlap 31.6 of 32.0 s
# 	hyp (ln 16 m1.0, ln 18 m4.9), ref (ln 16, ln 18)
# p93_q8: hyp (157.0 s,174.4 s), ref (157.7 s,174.8 s), overlap 16.8 of 17.1 s
# 	hyp (ln 19 m4.7, ln 21 m3.9), ref (ln 20, ln 21)
# p93_q9: hyp (176.5 s,198.1 s), ref (174.8 s,200.1 s), overlap 21.6 of 25.4 s
# 	hyp (ln 22 m1.7, ln 24 m3.3), ref (ln 22, ln 24)
# p94_q1: hyp (0.0 s,21.8 s), ref (0.0 s,22.0 s), overlap 21.8 of 22.0 s
# 	hyp (ln 1 m1.0, ln 3 m4.9), ref (ln 1, ln 3)
# p94_q10: hyp (206.2 s,229.8 s), ref (206.0 s,230.0 s), overlap 23.5 of 24.0 s
# 	hyp (ln 27 m1.1, ln 29 m4.9), ref (ln 27, ln 29)
# p94_q2: hyp (46.0 s,69.8 s), ref (46.0 s,70.0 s), overlap 23.8 of 24.0 s
# 	hyp (ln 7 m1.0, ln 9 m4.9), ref (ln 7, ln 9)
# p94_q3: hyp (117.8 s,141.5 s), ref (118.0 s,142.0 s), overlap 23.5 of 24.0 s
# 	hyp (ln 15 m4.9, ln 18 m4.8), ref (ln 16, ln 18)
# p94_q4: hyp (158.0 s,181.8 s), ref (158.0 s,182.0 s), overlap 23.8 of 24.0 s
# 	hyp (ln 21 m1.0, ln 23 m4.9), ref (ln 21, ln 23)
# p94_q5: hyp (229.5 s,250.3 s), ref (230.0 s,254.0 s), overlap 20.3 of 24.0 s
# 	hyp (ln 29 m4.8, ln 32 m3.1), ref (ln 30, ln 32)
# p94_q6: hyp (38.5 s,61.8 s), ref (38.0 s,62.0 s), overlap 23.2 of 24.0 s
# 	hyp (ln 6 m1.2, ln 8 m4.9), ref (ln 6, ln 8)
# p94_q7: hyp (69.9 s,93.5 s), ref (70.0 s,94.0 s), overlap 23.5 of 24.0 s
# 	hyp (ln 9 m4.9, ln 12 m4.8), ref (ln 10, ln 12)
# p94_q8: hyp (85.8 s,109.8 s), ref (86.0 s,110.0 s), overlap 23.8 of 24.0 s
# 	hyp (ln 11 m4.9, ln 14 m4.9), ref (ln 12, ln 14)
# p94_q9: hyp (126.0 s,149.1 s), ref (126.0 s,150.0 s), overlap 23.1 of 24.0 s
# 	hyp (ln 17 m1.0, ln 19 m4.6), ref (ln 17, ln 19)
# p95_q1: hyp (0.0 s,51.0 s), ref (0.0 s,48.8 s), overlap 48.8 of 48.8 s
# 	hyp (ln 1 m1.0, ln 5 m1.9), ref (ln 1, ln 4)
# p95_q10: hyp (227.1 s,267.6 s), ref (228.8 s,275.6 s), overlap 38.7 of 46.7 s
# 	hyp (ln -1 m-1.0, ln 20 m6.0), ref (ln 18, ln 20)
# p95_q2: hyp (36.4 s,70.6 s), ref (36.4 s,70.9 s), overlap 34.2 of 34.6 s
# 	hyp (ln 4 m1.0, ln 6 m4.9), ref (ln 4, ln 6)
# p95_q3: hyp (95.6 s,142.8 s), ref (96.5 s,144.8 s), overlap 46.3 of 48.3 s
# 	hyp (ln 8 m5.7, ln 11 m8.3), ref (ln 9, ln 11)
# p95_q4: hyp (218.3 s,250.6 s), ref (216.5 s,250.6 s), overlap 32.3 of 34.1 s
# 	hyp (ln 17 m1.8, ln 19 m5.0), ref (ln 17, ln 19)
# p95_q5: hyp (70.6 s,105.2 s), ref (73.3 s,108.6 s), overlap 31.9 of 35.3 s
# 	hyp (ln 6 m4.9, ln 9 m4.6), ref (ln 7, ln 9)
# p95_q6: hyp (37.5 s,70.9 s), ref (36.4 s,70.9 s), overlap 33.4 of 34.6 s
# 	hyp (ln 4 m1.5, ln 6 m5.0), ref (ln 4, ln 6)
# p95_q7: hyp (69.2 s,118.3 s), ref (73.3 s,108.6 s), overlap 35.3 of 35.3 s
# 	hyp (ln 6 m4.3, ln 10 m5.1), ref (ln 7, ln 9)
# p95_q8: hyp (174.3 s,210.8 s), ref (175.0 s,203.7 s), overlap 28.7 of 28.7 s
# 	hyp (ln 13 m6.7, ln 16 m3.8), ref (ln 14, ln 15)
# p95_q9: hyp (203.7 s,250.6 s), ref (203.7 s,236.1 s), overlap 32.4 of 32.4 s
# 	hyp (ln 15 m5.0, ln 19 m5.0), ref (ln 16, ln 18)
# p96_q1: hyp (2.3 s,28.4 s), ref (0.0 s,30.9 s), overlap 26.1 of 30.9 s
# 	hyp (ln 1 m1.8, ln 3 m4.1), ref (ln 1, ln 3)
# p96_q10: hyp (165.5 s,187.5 s), ref (163.1 s,188.4 s), overlap 22.0 of 25.3 s
# 	hyp (ln 24 m1.8, ln 26 m2.7), ref (ln 24, ln 26)
# p96_q2: hyp (39.8 s,55.3 s), ref (39.4 s,56.2 s), overlap 15.5 of 16.9 s
# 	hyp (ln 5 m1.2, ln 6 m3.7), ref (ln 5, ln 6)
# p96_q3: hyp (72.3 s,89.8 s), ref (73.1 s,90.0 s), overlap 16.7 of 16.9 s
# 	hyp (ln 8 m3.7, ln 11 m2.9), ref (ln 9, ln 11)
# p96_q4: hyp (113.0 s,125.8 s), ref (112.5 s,129.4 s), overlap 12.7 of 16.9 s
# 	hyp (ln 16 m1.2, ln 18 m1.7), ref (ln 16, ln 18)
# p96_q5: hyp (129.3 s,140.5 s), ref (129.4 s,140.6 s), overlap 11.1 of 11.2 s
# 	hyp (ln 18 m3.0, ln 20 m2.9), ref (ln 19, ln 20)
# p96_q6: hyp (47.8 s,67.5 s), ref (47.8 s,73.1 s), overlap 19.7 of 25.3 s
# 	hyp (ln 5 m4.0, ln 8 m2.0), ref (ln 6, ln 8)
# p96_q7: hyp (84.2 s,101.1 s), ref (84.4 s,101.2 s), overlap 16.7 of 16.9 s
# 	hyp (ln 10 m2.9, ln 13 m2.9), ref (ln 11, ln 13)
# p96_q8: hyp (101.2 s,112.3 s), ref (101.2 s,112.5 s), overlap 11.1 of 11.2 s
# 	hyp (ln 14 m1.0, ln 15 m2.9), ref (ln 14, ln 15)
# p96_q9: hyp (147.7 s,162.7 s), ref (149.1 s,163.1 s), overlap 13.6 of 14.1 s
# 	hyp (ln 21 m3.5, ln 23 m3.8), ref (ln 22, ln 23)
# p97_q1: hyp (217.0 s,240.4 s), ref (217.4 s,240.7 s), overlap 23.0 of 23.4 s
# 	hyp (ln 30 m8.7, ln 33 m8.7), ref (ln 31, ln 33)
# p97_q10: hyp (178.0 s,189.1 s), ref (178.2 s,189.3 s), overlap 11.0 of 11.1 s
# 	hyp (ln 24 m5.8, ln 27 m6.8), ref (ln 25, ln 27)
# p97_q2: hyp (275.0 s,297.4 s), ref (275.0 s,297.8 s), overlap 22.5 of 22.8 s
# 	hyp (ln 38 m8.0, ln 41 m7.7), ref (ln 39, ln 41)
# p97_q3: hyp (314.8 s,335.6 s), ref (314.8 s,335.8 s), overlap 20.9 of 21.0 s
# 	hyp (ln 43 m9.0, ln 46 m6.9), ref (ln 44, ln 46)
# p97_q4: hyp (401.3 s,424.0 s), ref (401.2 s,425.2 s), overlap 22.8 of 24.0 s
# 	hyp (ln 55 m1.1, ln 57 m8.0), ref (ln 55, ln 57)
# p97_q5: hyp (563.2 s,581.8 s), ref (556.2 s,577.2 s), overlap 14.0 of 21.0 s
# 	hyp (ln 79 m1.0, ln 81 m6.8), ref (ln 78, ln 80)
# p97_q6: hyp (6.2 s,36.8 s), ref (6.4 s,37.0 s), overlap 30.4 of 30.5 s
# 	hyp (ln 1 m4.8, ln 4 m6.9), ref (ln 2, ln 4)
# p97_q7: hyp (51.2 s,73.9 s), ref (51.4 s,73.9 s), overlap 22.4 of 22.5 s
# 	hyp (ln 6 m5.8, ln 9 m4.0), ref (ln 7, ln 9)
# p97_q8: hyp (90.0 s,102.8 s), ref (90.0 s,110.9 s), overlap 12.8 of 20.9 s
# 	hyp (ln 12 m1.0, ln 13 m5.0), ref (ln 12, ln 14)
# p97_q9: hyp (122.1 s,142.0 s), ref (122.1 s,143.0 s), overlap 19.8 of 20.9 s
# 	hyp (ln 16 m5.0, ln 19 m6.3), ref (ln 17, ln 19)
# p98_q1: hyp (240.5 s,252.6 s), ref (240.0 s,253.1 s), overlap 12.0 of 13.1 s
# 	hyp (ln 47 m1.7, ln 49 m6.4), ref (ln 47, ln 49)
# p98_q10: hyp (228.3 s,235.6 s), ref (227.7 s,235.9 s), overlap 7.3 of 8.2 s
# 	hyp (ln 44 m1.7, ln 45 m5.6), ref (ln 44, ln 45)
# p98_q2: hyp (265.6 s,283.2 s), ref (265.3 s,282.4 s), overlap 16.7 of 17.1 s
# 	hyp (ln 52 m1.3, ln 55 m1.8), ref (ln 52, ln 54)
# p98_q3: hyp (296.4 s,312.4 s), ref (294.7 s,312.0 s), overlap 15.6 of 17.3 s
# 	hyp (ln 57 m2.8, ln 60 m1.5), ref (ln 57, ln 59)
# p98_q4: hyp (322.1 s,327.1 s), ref (321.7 s,331.5 s), overlap 5.0 of 9.8 s
# 	hyp (ln 62 m1.5, ln 63 m3.7), ref (ln 62, ln 64)
# p98_q5: hyp (336.9 s,352.8 s), ref (339.7 s,352.0 s), overlap 12.3 of 12.3 s
# 	hyp (ln 66 m2.6, ln 70 m2.0), ref (ln 67, ln 69)
# p98_q6: hyp (1.8 s,11.2 s), ref (4.2 s,14.4 s), overlap 7.0 of 10.2 s
# 	hyp (ln 1 m4.0, ln 3 m5.8), ref (ln 2, ln 4)
# p98_q7: hyp (105.5 s,121.3 s), ref (105.3 s,121.5 s), overlap 15.7 of 16.3 s
# 	hyp (ln 21 m1.3, ln 23 m6.7), ref (ln 21, ln 23)
# p98_q8: hyp (380.3 s,393.3 s), ref (158.4 s,172.1 s), overlap 0.0 of 13.7 s
# 	hyp (ln 76 m2.7, ln 78 m4.5), ref (ln 31, ln 33)
# p98_q9: hyp (198.3 s,213.3 s), ref (197.8 s,213.3 s), overlap 15.0 of 15.4 s
# 	hyp (ln 38 m1.5, ln 41 m1.0), ref (ln 38, ln 40)
# p99_q1: hyp (152.6 s,165.5 s), ref (150.4 s,163.4 s), overlap 10.8 of 13.0 s
# 	hyp (ln 31 m2.9, ln 34 m2.8), ref (ln 31, ln 33)
# p99_q10: hyp (135.6 s,143.9 s), ref (132.3 s,141.8 s), overlap 6.2 of 9.5 s
# 	hyp (ln 26 m2.9, ln 29 m2.9), ref (ln 26, ln 28)
# p99_q2: hyp (197.0 s,207.6 s), ref (180.7 s,203.0 s), overlap 6.0 of 22.4 s
# 	hyp (ln 39 m1.3, ln 40 m3.0), ref (ln 37, ln 39)
# p99_q3: hyp (211.1 s,223.3 s), ref (209.8 s,221.1 s), overlap 10.0 of 11.2 s
# 	hyp (ln 41 m2.1, ln 44 m2.9), ref (ln 41, ln 43)
# p99_q4: hyp (219.8 s,230.2 s), ref (217.7 s,227.8 s), overlap 8.1 of 10.1 s
# 	hyp (ln 43 m2.8, ln 46 m3.1), ref (ln 43, ln 45)
# p99_q5: hyp (34.5 s,41.0 s), ref (235.7 s,245.8 s), overlap 0.0 of 10.1 s
# 	hyp (ln 9 m1.9, ln 11 m1.7), ref (ln 48, ln 50)
# p99_q6: hyp (10.8 s,22.1 s), ref (11.0 s,23.4 s), overlap 11.2 of 12.4 s
# 	hyp (ln 2 m4.8, ln 5 m3.9), ref (ln 3, ln 5)
# p99_q7: hyp (30.0 s,39.7 s), ref (30.1 s,40.2 s), overlap 9.6 of 10.1 s
# 	hyp (ln 7 m3.9, ln 10 m3.5), ref (ln 8, ln 10)
# p99_q8: hyp (50.3 s,61.6 s), ref (50.4 s,63.9 s), overlap 11.2 of 13.5 s
# 	hyp (ln 13 m3.9, ln 15 m7.0), ref (ln 14, ln 15)
# p99_q9: hyp (113.0 s,133.7 s), ref (111.2 s,132.3 s), overlap 19.3 of 21.1 s
# 	hyp (ln 23 m2.5, ln 26 m2.0), ref (ln 23, ln 25)
# p9_q1: hyp (168.2 s,183.3 s), ref (0.8 s,19.2 s), overlap 0.0 of 18.4 s
# 	hyp (ln 24 m4.3, ln 26 m1.8), ref (ln 1, ln 2)
# p9_q10: hyp (214.4 s,227.6 s), ref (214.5 s,229.4 s), overlap 13.1 of 14.9 s
# 	hyp (ln 29 m5.9, ln 31 m5.3), ref (ln 30, ln 31)
# p9_q2: hyp (7.3 s,37.7 s), ref (8.5 s,37.8 s), overlap 29.2 of 29.3 s
# 	hyp (ln 1 m7.0, ln 4 m7.9), ref (ln 2, ln 4)
# p9_q3: hyp (20.4 s,42.4 s), ref (19.2 s,42.6 s), overlap 22.0 of 23.4 s
# 	hyp (ln 3 m1.9, ln 5 m4.9), ref (ln 3, ln 5)
# p9_q4: hyp (30.2 s,42.5 s), ref (29.2 s,42.6 s), overlap 12.2 of 13.3 s
# 	hyp (ln 4 m1.7, ln 5 m4.9), ref (ln 4, ln 5)
# p9_q5: hyp (52.0 s,68.6 s), ref (50.8 s,69.1 s), overlap 16.6 of 18.3 s
# 	hyp (ln 7 m2.0, ln 9 m4.6), ref (ln 7, ln 9)
# p9_q6: hyp (115.7 s,126.9 s), ref (116.3 s,128.6 s), overlap 10.6 of 12.2 s
# 	hyp (ln 15 m6.4, ln 17 m4.6), ref (ln 16, ln 17)
# p9_q7: hyp (145.7 s,163.4 s), ref (145.8 s,164.2 s), overlap 17.6 of 18.4 s
# 	hyp (ln 20 m4.9, ln 23 m8.3), ref (ln 21, ln 23)
# p9_q8: hyp (182.5 s,214.4 s), ref (182.3 s,214.5 s), overlap 31.9 of 32.2 s
# 	hyp (ln 26 m1.2, ln 29 m5.9), ref (ln 26, ln 29)
# p9_q9: hyp (195.8 s,218.8 s), ref (202.5 s,222.7 s), overlap 16.3 of 20.2 s
# 	hyp (ln 27 m3.7, ln 30 m4.7), ref (ln 28, ln 30)
