# %%
# %matplotlib inline

# %%
import numpy as np
import matplotlib.pyplot as plt
import glob
import os.path
import pretty_midi

# to remove later
import re

# %% [markdown]
# ### Generate ground truth labels

# %%
def importScoreInfo(scoreDir):
    d = {}
    for csvfile in glob.glob("{}/p*1.scoreinfo.csv".format(scoreDir)): ### TO DO: REMOVE 1
        pieceStr = os.path.basename(csvfile).split('.')[0]  # e.g. 'p7'
        d[pieceStr] = {}
        with open(csvfile, 'r') as f:
            next(f) # skip header
            for line in f:
                parts = line.rstrip().split(',')
                linenum = int(parts[0])
                startmeasure = int(parts[1])
                endmeasure = int(parts[2])
                d[pieceStr][linenum] = (startmeasure, endmeasure)
    return d

# %%
scoreDir = 'data/score_info'
scoreInfo = importScoreInfo(scoreDir)

# %%
def importMidiInfo(midiInfoDir, midiDir):
    d = {}
    for csvfile in glob.glob("{}/p*1_midinfo.csv".format(midiInfoDir)): ### TO DO: REMOVE 1
        pieceStr = os.path.basename(csvfile).split('_')[0]  # e.g. 'p7'
        d[pieceStr] = {}
        with open(csvfile, 'r') as f:
            for line in f:
                parts = line.rstrip().split(',')
                measure = int(parts[0])
                time = float(parts[1])
                d[pieceStr][measure] = time
        
        # add an additional entry to indicate the total duration
        midfile = "{}/{}.mid".format(midiDir, pieceStr)
        mid = pretty_midi.PrettyMIDI(midfile)
        totalDur = mid.get_piano_roll().shape[1] * .01 # default fs = 100
        d[pieceStr][measure+1] = totalDur
                
    return d

# %%
midiInfoDir = 'data/midi_info'
midiDir = 'data/midi'
midiInfo = importMidiInfo(midiInfoDir, midiDir)
# Out:
# /anaconda3/envs/sheetmidiretrieval/lib/python3.6/site-packages/pretty_midi/pretty_midi.py:100: RuntimeWarning: Tempo, Key or Time signature change events found on non-zero tracks.  This is not a valid type 0 or type 1 MIDI file.  Tempo, Key or Time Signature may be wrong.
#   RuntimeWarning)

# %%
def getQueryGroundTruth(infile, multMatchFile, scoreInfo, midiInfo):
    # infers ground truth timestamps for each query
    d = {}
    with open(infile, 'r') as fin: 
        next(fin) # skip header
        for line in fin:

            # get start, end lines
            parts = line.rstrip().split(',')  # e.g. 'p1_q1,0,3'
            queryStr = parts[0]
            startLine = int(parts[1])
            endLine = int(parts[2])

            # infer start, end measure
            pieceStr = queryStr.split('_')[0]

            m = re.search(r'^p\d*1$', pieceStr) ### TO DO: REMOVE
            if not m: # doesn't match
                continue

            #print("%s,%s,%s" % (queryStr, startLine,endLine))            
            startMeasure = scoreInfo[pieceStr][startLine][0]
            endMeasure = scoreInfo[pieceStr][endLine][1]

            # infer start, end time
            #print("%s,%s,%s" % (queryStr, startMeasure, endMeasure))
            startTime = midiInfo[pieceStr][startMeasure]
            endTime = midiInfo[pieceStr][endMeasure+1] # ends on downbeat of next measure

            d[queryStr] = [(startTime, endTime, startMeasure, endMeasure, startLine, endLine)]

    addMultipleMatches(d, multMatchFile, scoreInfo, midiInfo)
            
    return d

# %%
def addMultipleMatches(d, multMatchFile, scoreInfo, midiInfo):
    # some queries match more than 1 segment of the score, these are indicated in multMatchFile
    with open(multMatchFile, 'r') as f:
        for line in f:
            
            # parse line 
            parts = line.rstrip().split(',')  # e.g. 'p31_q8,L3m6,L5m1'
            queryStr = parts[0]
            pieceStr = queryStr.split('_')[0]
            startStr = parts[1]
            endStr = parts[2]
            
            # infer start, end measure
            startLine = int(startStr.split('m')[0][1:])
            endLine = int(endStr.split('m')[0][1:])
            startOffset = int(startStr.split('m')[1])
            endOffset = int(endStr.split('m')[1])
            startMeasure = scoreInfo[pieceStr][startLine][0] + startOffset - 1
            endMeasure = scoreInfo[pieceStr][endLine][0] + endOffset - 1
            
            # infer start, end time
            startTime = midiInfo[pieceStr][startMeasure]
            endTime = midiInfo[pieceStr][endMeasure+1] # ends on downbeat of next measure
            
            tup = (startTime, endTime, startMeasure, endMeasure, startStr, endStr) # startStr more informative than startLine
            d[queryStr].append(tup)
            
    return d

# %%
def saveQueryInfoToFile(d, outfile):
    with open(outfile, 'w') as f:
        for query in sorted(d):
            for (tstart, tend, mstart, mend, lstart, lend) in d[query]:
                f.write('{},{:.2f},{:.2f},{},{},{},{}\n'.format(query, tstart, tend, mstart, mend, lstart, lend))

# %%
queryInfoFile = 'data/query_info/query_info.csv' # to read
multMatchesFile = 'data/query_info/query.multmatches' # to read
queryGTFile = 'data/query_info/query.gt' # to write
queryInfo = getQueryGroundTruth(queryInfoFile, multMatchesFile, scoreInfo, midiInfo)
saveQueryInfoToFile(queryInfo, queryGTFile)

# %% [markdown]
# ### Evaluate system performance

# %%
def readGroundTruthLabels(gtfile):
    d = {}
    with open(gtfile, 'r') as f:
        for line in f:
            parts = line.rstrip().split(',') # e.g. 'p1_q1,1.55,32.59'
            queryStr = parts[0]
            tstart = float(parts[1])
            tend = float(parts[2])
            if queryStr in d:
                d[queryStr].append((tstart, tend))
            else:
                d[queryStr] = [(tstart, tend)]
    return d

# %%
def readHypothesisFiles(hypdir):
    l = []
    for hypfile in sorted(glob.glob("{}/*.hyp".format(hypdir))):
        with open(hypfile, 'r') as f:
            line = next(f)
            parts = line.rstrip().split(',')
            query = parts[0]  # e.g. p1_q1
            tstart = float(parts[1])
            tend = float(parts[2])
            l.append((query, tstart, tend))
    return l

# %%
def calcPrecisionRecall(hypdir, gtfile):
    d = readGroundTruthLabels(gtfile)
    hyps = readHypothesisFiles(hypdir)
    hypinfo = [] 
    overlapTotal, hypTotal, refTotal = (0,0,0)
    for (queryid, hypstart, hypend) in hyps:
        refSegments = d[queryid]
        idxMax = 0
        overlapMax = 0
        for i, refSegment in enumerate(refSegments): # find ref segment with most overlap
            overlap = calcOverlap((hypstart, hypend), refSegment)
            if overlap > overlapMax:
                idxMax = i
                overlapMax = overlap
        hyplen = hypend - hypstart
        reflen = refSegments[idxMax][1] - refSegments[idxMax][0]        
        overlapTotal += overlapMax
        hypTotal += hyplen
        refTotal += reflen
        hypinfo.append((queryid, overlap, refSegments[idxMax][0], refSegments[idxMax][1], idxMax)) # keep for error analysis
    P = overlapTotal / hypTotal
    R = overlapTotal / refTotal
    F = 2 * P * R / (P + R)
    return F, P, R, hypinfo

# %%
def calcOverlap(seg1, seg2):
    overlap_lb = max(seg1[0], seg2[0])
    overlap_ub = min(seg1[1], seg2[1])
    overlap = np.clip(overlap_ub - overlap_lb, 0, None)
    return overlap

# %%
hypdir = 'experiments/exp1/hyp'
F, P, R, hypinfo = calcPrecisionRecall(hypdir, queryGTFile)

# %%
F, P, R, len(hypinfo)
# Out:
# (0.7791053331159173, 0.7466815049842541, 0.8144729297635711, 100)

# %% [markdown]
# ### Investigate Errors

# %%
def printDebuggingInfo(hypdir, gtfile, scoreInfo, midiInfo, queryInfo, hypInfo):
    d = readGroundTruthLabels(gtfile)
    hyps = readHypothesisFiles(hypdir)
    for i, (query, hyp_tstart, hyp_tend) in enumerate(hyps):
        
        # hyp and ref info (sec)
        piece = query.split('_')[0]
        _, overlap, ref_tstart, ref_tend, bestIdx = hypInfo[i]
        
        # hyp and ref info (measures)
        interp_m = list(midiInfo[piece].keys())
        interp_t = [midiInfo[piece][m] for m in interp_m]
        hyp_mstart, hyp_mend, ref_mstart, ref_mend = np.interp([hyp_tstart, hyp_tend, ref_tstart, ref_tend], interp_t, interp_m)
        moverlap = calcOverlap((hyp_mstart, hyp_mend),(ref_mstart, ref_mend))
        
        # hyp and ref info (line # + measure offset)
        hyp_lstart, hyp_lstartoff = getLineNumberMeasureOffset(hyp_mstart, scoreInfo[piece])
        hyp_lend, hyp_lendoff = getLineNumberMeasureOffset(hyp_mend, scoreInfo[piece])
        ref_lstart = queryInfo[query][bestIdx][4]
        ref_lend = queryInfo[query][bestIdx][5]
        
        # compare in sec
        print("{}: hyp ({:.1f} s,{:.1f} s), ref ({:.1f} s,{:.1f} s), overlap {:.1f} of {:.1f} s".format(query, hyp_tstart, hyp_tend, ref_tstart, ref_tend, overlap, ref_tend - ref_tstart))
        
        # compare in measure numbers
        #print("\thyp ({:.1f} m, {:.1f} m), ref ({:.1f} m, {:.1f} m), overlap {:.1f} m".format(hyp_mstart, hyp_mend, ref_mstart, ref_mend, moverlap))
        
        # compare in line + measure offset
        print("\thyp (ln {} m{:.1f}, ln {} m{:.1f}), ref (ln {}, ln {})".format(hyp_lstart, hyp_lstartoff, hyp_lend, hyp_lendoff, ref_lstart, ref_lend))
    return

# %%
def getLineNumberMeasureOffset(measureNum, d):
    line = -1
    moffset = -1
    for key in d:
        lb, ub = d[key] # line start, end measure 
        if measureNum >= lb and measureNum < ub + 1:
            line = key
            moffset = measureNum - lb + 1
            break
    return line, moffset

# %%
printDebuggingInfo(hypdir, queryGTFile, scoreInfo, midiInfo, queryInfo, hypinfo)
# Out:
# p11_q1: hyp (35.8 s,58.0 s), ref (1.6 s,25.1 s), overlap 0.0 of 23.4 s
# 	hyp (ln 4 m1.4, ln 6 m1.4), ref (ln 1, ln 2)
# p11_q10: hyp (534.1 s,549.1 s), ref (536.3 s,550.9 s), overlap 12.9 of 14.6 s
# 	hyp (ln 76 m2.7, ln 79 m3.0), ref (ln 77, ln 79)
# p11_q2: hyp (26.5 s,54.8 s), ref (25.1 s,57.2 s), overlap 28.3 of 32.1 s
# 	hyp (ln 3 m1.7, ln 5 m4.8), ref (ln 3, ln 5)
# p11_q3: hyp (64.3 s,83.4 s), ref (65.0 s,83.6 s), overlap 18.4 of 18.6 s
# 	hyp (ln 6 m4.7, ln 9 m3.9), ref (ln 7, ln 9)
# p11_q4: hyp (101.7 s,116.9 s), ref (83.6 s,111.5 s), overlap 9.9 of 28.0 s
# 	hyp (ln 11 m6.6, ln 13 m3.4), ref (ln 10, ln 12)
# p11_q5: hyp (189.0 s,209.4 s), ref (189.6 s,209.5 s), overlap 19.8 of 20.0 s
# 	hyp (ln 23 m3.7, ln 26 m5.9), ref (ln 24, ln 26)
# p11_q6: hyp (224.8 s,253.0 s), ref (225.3 s,248.8 s), overlap 23.5 of 23.5 s
# 	hyp (ln 28 m4.7, ln 32 m2.9), ref (ln 29, ln 31)
# p11_q7: hyp (34.7 s,54.8 s), ref (34.8 s,57.2 s), overlap 20.0 of 22.4 s
# 	hyp (ln 3 m5.0, ln 5 m4.8), ref (ln 4, ln 5)
# p11_q8: hyp (323.9 s,353.7 s), ref (327.4 s,354.6 s), overlap 26.4 of 27.2 s
# 	hyp (ln 44 m2.9, ln 47 m5.6), ref (ln 45, ln 47)
# p11_q9: hyp (528.5 s,547.4 s), ref (499.6 s,526.8 s), overlap 0.0 of 27.1 s
# 	hyp (ln 75 m2.1, ln 79 m2.0), ref (ln 72, ln 74)
# p1_q1: hyp (0.0 s,29.4 s), ref (0.0 s,29.5 s), overlap 29.4 of 29.5 s
# 	hyp (ln 1 m1.0, ln 3 m5.0), ref (ln 1, ln 3)
# p1_q10: hyp (225.6 s,250.7 s), ref (226.1 s,250.9 s), overlap 24.6 of 24.8 s
# 	hyp (ln 19 m4.8, ln 22 m3.9), ref (ln 20, ln 22)
# p1_q2: hyp (16.8 s,51.0 s), ref (17.1 s,51.2 s), overlap 33.9 of 34.1 s
# 	hyp (ln 2 m3.9, ln 5 m4.9), ref (ln 3, ln 5)
# p1_q3: hyp (38.3 s,63.4 s), ref (38.8 s,63.6 s), overlap 24.6 of 24.8 s
# 	hyp (ln 4 m3.8, ln 6 m4.9), ref (ln 5, ln 6)
# p1_q4: hyp (62.8 s,89.3 s), ref (63.6 s,89.6 s), overlap 25.7 of 25.9 s
# 	hyp (ln 6 m4.7, ln 8 m4.9), ref (ln 7, ln 8)
# p1_q5: hyp (76.4 s,115.2 s), ref (76.7 s,115.4 s), overlap 38.4 of 38.7 s
# 	hyp (ln 7 m4.9, ln 10 m4.9), ref (ln 8, ln 10)
# p1_q6: hyp (102.4 s,137.5 s), ref (102.7 s,137.7 s), overlap 34.8 of 35.1 s
# 	hyp (ln 9 m4.9, ln 12 m3.9), ref (ln 10, ln 12)
# p1_q7: hyp (135.9 s,162.8 s), ref (137.7 s,163.1 s), overlap 25.1 of 25.3 s
# 	hyp (ln 12 m3.4, ln 14 m4.9), ref (ln 13, ln 14)
# p1_q8: hyp (149.6 s,187.6 s), ref (149.8 s,187.9 s), overlap 37.8 of 38.0 s
# 	hyp (ln 13 m4.9, ln 16 m4.9), ref (ln 14, ln 16)
# p1_q9: hyp (187.6 s,212.4 s), ref (187.9 s,212.7 s), overlap 24.6 of 24.8 s
# 	hyp (ln 16 m4.9, ln 18 m4.9), ref (ln 17, ln 18)
# p21_q1: hyp (138.5 s,152.0 s), ref (138.9 s,151.7 s), overlap 12.8 of 12.8 s
# 	hyp (ln 38 m4.6, ln 42 m3.4), ref (ln L39m1, ln L42m2)
# p21_q10: hyp (17.8 s,26.9 s), ref (18.0 s,24.9 s), overlap 6.9 of 6.9 s
# 	hyp (ln 5 m2.8, ln 7 m3.4), ref (ln L5m3, ln L6m5)
# p21_q2: hyp (20.0 s,31.5 s), ref (20.6 s,31.7 s), overlap 11.0 of 11.1 s
# 	hyp (ln 5 m5.4, ln 8 m4.8), ref (ln 6, ln 8)
# p21_q3: hyp (24.3 s,37.2 s), ref (38.6 s,49.7 s), overlap 0.0 of 11.1 s
# 	hyp (ln 6 m5.4, ln 10 m3.5), ref (ln 11, ln 13)
# p21_q4: hyp (45.1 s,58.4 s), ref (45.4 s,58.3 s), overlap 12.9 of 12.9 s
# 	hyp (ln 12 m4.6, ln 16 m1.1), ref (ln 13, ln 15)
# p21_q5: hyp (64.9 s,75.3 s), ref (65.1 s,75.4 s), overlap 10.2 of 10.3 s
# 	hyp (ln 17 m4.8, ln 20 m4.9), ref (ln 18, ln 20)
# p21_q6: hyp (82.0 s,93.5 s), ref (82.3 s,93.4 s), overlap 11.1 of 11.1 s
# 	hyp (ln 22 m4.6, ln 26 m1.1), ref (ln 23, ln 25)
# p21_q7: hyp (100.0 s,111.3 s), ref (100.3 s,111.4 s), overlap 11.0 of 11.1 s
# 	hyp (ln 27 m4.6, ln 30 m5.9), ref (ln 28, ln 30)
# p21_q8: hyp (111.0 s,122.3 s), ref (111.4 s,121.7 s), overlap 10.3 of 10.3 s
# 	hyp (ln 30 m5.5, ln 34 m1.7), ref (ln 31, ln 33)
# p21_q9: hyp (131.6 s,142.9 s), ref (132.0 s,143.1 s), overlap 10.9 of 11.1 s
# 	hyp (ln 36 m4.6, ln 39 m5.7), ref (ln 37, ln 39)
# p31_q1: hyp (2.1 s,14.7 s), ref (0.0 s,15.5 s), overlap 12.6 of 15.5 s
# 	hyp (ln 1 m3.0, ln 2 m7.2), ref (ln 1, ln 2)
# p31_q10: hyp (139.2 s,155.8 s), ref (137.1 s,158.1 s), overlap 16.6 of 21.0 s
# 	hyp (ln 19 m3.0, ln 21 m6.7), ref (ln 19, ln 21)
# p31_q2: hyp (2.5 s,23.7 s), ref (0.0 s,23.9 s), overlap 21.1 of 23.9 s
# 	hyp (ln 1 m3.4, ln 3 m8.8), ref (ln 1, ln 3)
# p31_q3: hyp (8.2 s,32.1 s), ref (8.2 s,32.2 s), overlap 23.8 of 24.0 s
# 	hyp (ln 1 m9.0, ln 4 m8.8), ref (ln 2, ln 4)
# p31_q4: hyp (15.5 s,39.2 s), ref (15.5 s,40.0 s), overlap 23.7 of 24.5 s
# 	hyp (ln 2 m8.0, ln 5 m7.5), ref (ln 3, ln 5)
# p31_q5: hyp (22.8 s,39.2 s), ref (23.9 s,40.0 s), overlap 15.4 of 16.1 s
# 	hyp (ln 3 m8.0, ln 5 m7.5), ref (ln 4, ln 5)
# p31_q6: hyp (42.5 s,63.7 s), ref (40.0 s,64.1 s), overlap 21.2 of 24.1 s
# 	hyp (ln 6 m3.4, ln 8 m8.7), ref (ln 6, ln 8)
# p31_q7: hyp (55.1 s,79.6 s), ref (55.5 s,80.0 s), overlap 24.1 of 24.5 s
# 	hyp (ln 7 m7.7, ln 10 m7.7), ref (ln 8, ln 10)
# p31_q8: hyp (20.4 s,33.1 s), ref (20.7 s,33.3 s), overlap 12.4 of 12.6 s
# 	hyp (ln 3 m5.7, ln 5 m1.8), ref (ln L3m6, ln L5m1)
# p31_q9: hyp (33.3 s,54.1 s), ref (33.3 s,54.5 s), overlap 20.8 of 21.2 s
# 	hyp (ln 5 m2.0, ln 7 m6.7), ref (ln L5m2, ln L7m6)
# p41_q1: hyp (60.4 s,74.1 s), ref (62.2 s,74.5 s), overlap 12.0 of 12.4 s
# 	hyp (ln 10 m3.0, ln 12 m2.5), ref (ln L10m5, ln L12m2)
# p41_q10: hyp (72.6 s,92.2 s), ref (72.9 s,93.3 s), overlap 19.3 of 20.4 s
# 	hyp (ln 11 m7.7, ln 14 m9.0), ref (ln 12, ln 14)
# p41_q2: hyp (60.7 s,81.0 s), ref (62.2 s,81.1 s), overlap 18.8 of 18.9 s
# 	hyp (ln 10 m3.3, ln 13 m2.8), ref (ln L10m5, ln L13m2)
# p41_q3: hyp (11.8 s,38.6 s), ref (12.3 s,31.5 s), overlap 19.1 of 19.1 s
# 	hyp (ln 2 m7.4, ln 6 m9.3), ref (ln 3, ln 5)
# p41_q4: hyp (18.1 s,45.3 s), ref (18.9 s,39.1 s), overlap 20.2 of 20.2 s
# 	hyp (ln 3 m8.0, ln 8 m1.3), ref (ln 4, ln 6)
# p41_q5: hyp (30.5 s,45.9 s), ref (31.5 s,45.0 s), overlap 13.6 of 13.6 s
# 	hyp (ln 5 m7.8, ln 8 m2.0), ref (ln 6, ln 7)
# p41_q6: hyp (44.9 s,66.7 s), ref (45.0 s,58.6 s), overlap 13.6 of 13.6 s
# 	hyp (ln 7 m7.9, ln 10 m10.5), ref (ln 8, ln 9)
# p41_q7: hyp (44.9 s,67.0 s), ref (45.0 s,67.1 s), overlap 21.9 of 22.1 s
# 	hyp (ln 7 m7.9, ln 10 m10.8), ref (ln 8, ln 10)
# p41_q8: hyp (58.4 s,79.2 s), ref (58.6 s,79.5 s), overlap 20.6 of 20.9 s
# 	hyp (ln 9 m8.8, ln 12 m8.7), ref (ln 10, ln 12)
# p41_q9: hyp (67.0 s,92.2 s), ref (67.1 s,85.3 s), overlap 18.2 of 18.2 s
# 	hyp (ln 10 m10.8, ln 14 m9.0), ref (ln 11, ln 13)
# p51_q1: hyp (0.0 s,11.5 s), ref (0.0 s,8.8 s), overlap 8.8 of 8.8 s
# 	hyp (ln 1 m1.0, ln 3 m4.7), ref (ln 1, ln 2)
# p51_q10: hyp (2.4 s,10.4 s), ref (43.2 s,52.3 s), overlap 0.0 of 9.1 s
# 	hyp (ln 1 m4.3, ln 3 m3.3), ref (ln 10, ln 11)
# p51_q2: hyp (0.0 s,26.0 s), ref (0.0 s,13.2 s), overlap 13.2 of 13.2 s
# 	hyp (ln 1 m1.0, ln 7 m1.5), ref (ln 1, ln 3)
# p51_q3: hyp (0.0 s,20.6 s), ref (4.4 s,17.6 s), overlap 13.2 of 13.2 s
# 	hyp (ln 1 m1.0, ln 5 m5.2), ref (ln 2, ln 4)
# p51_q4: hyp (6.4 s,22.5 s), ref (4.4 s,21.2 s), overlap 14.8 of 16.8 s
# 	hyp (ln 2 m3.7, ln 6 m2.8), ref (ln 2, ln 5)
# p51_q5: hyp (15.2 s,24.8 s), ref (17.6 s,25.6 s), overlap 7.2 of 8.1 s
# 	hyp (ln 4 m3.7, ln 6 m5.8), ref (ln 5, ln 6)
# p51_q6: hyp (23.4 s,37.9 s), ref (25.6 s,37.3 s), overlap 11.7 of 11.7 s
# 	hyp (ln 6 m4.0, ln 9 m1.8), ref (ln 7, ln 8)
# p51_q7: hyp (23.4 s,44.3 s), ref (25.6 s,43.2 s), overlap 17.6 of 17.6 s
# 	hyp (ln 6 m4.0, ln 10 m2.5), ref (ln 7, ln 9)
# p51_q8: hyp (11.3 s,27.6 s), ref (31.5 s,48.3 s), overlap 0.0 of 16.8 s
# 	hyp (ln 3 m4.5, ln 7 m3.7), ref (ln 8, ln 10)
# p51_q9: hyp (0.0 s,13.2 s), ref (37.3 s,52.3 s), overlap 0.0 of 15.0 s
# 	hyp (ln 1 m1.0, ln 3 m7.0), ref (ln 9, ln 11)
# p61_q1: hyp (172.8 s,186.2 s), ref (6.6 s,16.5 s), overlap 0.0 of 9.9 s
# 	hyp (ln 50 m4.4, ln 55 m3.3), ref (ln 3, ln 5)
# p61_q10: hyp (185.0 s,198.1 s), ref (103.1 s,114.7 s), overlap 0.0 of 11.5 s
# 	hyp (ln 55 m1.9, ln 59 m3.7), ref (ln 30, ln 32)
# p61_q2: hyp (176.1 s,189.1 s), ref (42.9 s,52.8 s), overlap 0.0 of 9.9 s
# 	hyp (ln 52 m1.4, ln 56 m3.8), ref (ln 14, ln 16)
# p61_q3: hyp (166.5 s,184.8 s), ref (60.2 s,76.7 s), overlap 0.0 of 16.5 s
# 	hyp (ln 48 m4.7, ln 55 m1.6), ref (ln 19, ln 21)
# p61_q4: hyp (173.3 s,177.7 s), ref (73.4 s,82.5 s), overlap 0.0 of 9.1 s
# 	hyp (ln 51 m1.0, ln 52 m3.2), ref (ln 21, ln 23)
# p61_q5: hyp (151.2 s,162.8 s), ref (92.4 s,103.1 s), overlap 0.0 of 10.7 s
# 	hyp (ln 43 m4.3, ln 47 m4.4), ref (ln 27, ln 29)
# p61_q6: hyp (0.0 s,9.9 s), ref (0.0 s,9.9 s), overlap 9.9 of 9.9 s
# 	hyp (ln 1 m1.0, ln 3 m5.0), ref (ln 1, ln 3)
# p61_q7: hyp (22.2 s,32.9 s), ref (23.1 s,33.0 s), overlap 9.8 of 9.9 s
# 	hyp (ln 7 m3.9, ln 10 m4.9), ref (ln 8, ln 10)
# p61_q8: hyp (182.7 s,195.1 s), ref (39.6 s,49.5 s), overlap 0.0 of 9.9 s
# 	hyp (ln 54 m2.0, ln 58 m4.1), ref (ln 13, ln 15)
# p61_q9: hyp (56.9 s,66.4 s), ref (56.9 s,73.4 s), overlap 9.4 of 16.5 s
# 	hyp (ln 17 m6.0, ln 20 m4.5), ref (ln 18, ln 20)
# p71_q1: hyp (0.0 s,15.6 s), ref (0.0 s,15.3 s), overlap 15.3 of 15.3 s
# 	hyp (ln 1 m1.0, ln 4 m1.2), ref (ln 1, ln 3)
# p71_q10: hyp (31.5 s,47.1 s), ref (31.7 s,47.4 s), overlap 15.4 of 15.7 s
# 	hyp (ln 7 m3.9, ln 10 m4.6), ref (ln 8, ln 10)
# p71_q2: hyp (9.5 s,23.4 s), ref (9.9 s,23.5 s), overlap 13.5 of 13.6 s
# 	hyp (ln 2 m4.7, ln 5 m3.9), ref (ln 3, ln 5)
# p71_q3: hyp (23.1 s,31.6 s), ref (23.5 s,31.7 s), overlap 8.1 of 8.2 s
# 	hyp (ln 5 m3.7, ln 7 m3.9), ref (ln 6, ln 7)
# p71_q4: hyp (26.8 s,42.5 s), ref (27.6 s,42.6 s), overlap 14.9 of 15.0 s
# 	hyp (ln 6 m3.4, ln 9 m4.9), ref (ln 7, ln 9)
# p71_q5: hyp (31.5 s,47.0 s), ref (31.7 s,47.4 s), overlap 15.3 of 15.7 s
# 	hyp (ln 7 m3.9, ln 10 m4.5), ref (ln 8, ln 10)
# p71_q6: hyp (0.0 s,16.0 s), ref (0.0 s,15.3 s), overlap 15.3 of 15.3 s
# 	hyp (ln 1 m1.0, ln 4 m1.5), ref (ln 1, ln 3)
# p71_q7: hyp (9.9 s,23.4 s), ref (9.9 s,23.5 s), overlap 13.5 of 13.6 s
# 	hyp (ln 3 m1.0, ln 5 m3.9), ref (ln 3, ln 5)
# p71_q8: hyp (23.1 s,31.6 s), ref (23.5 s,31.7 s), overlap 8.1 of 8.2 s
# 	hyp (ln 5 m3.7, ln 7 m3.9), ref (ln 6, ln 7)
# p71_q9: hyp (23.9 s,31.1 s), ref (27.6 s,42.6 s), overlap 3.5 of 15.0 s
# 	hyp (ln 6 m1.2, ln 7 m3.6), ref (ln 7, ln 9)
# p81_q1: hyp (8.3 s,87.2 s), ref (13.3 s,57.8 s), overlap 44.5 of 44.5 s
# 	hyp (ln 1 m3.5, ln 7 m1.9), ref (ln 2, ln 4)
# p81_q10: hyp (402.2 s,434.4 s), ref (417.5 s,426.9 s), overlap 9.5 of 9.5 s
# 	hyp (ln 40 m2.6, ln 43 m3.8), ref (ln 42, ln 42)
# p81_q2: hyp (228.2 s,280.6 s), ref (57.8 s,99.4 s), overlap 0.0 of 41.6 s
# 	hyp (ln 21 m1.8, ln 25 m1.8), ref (ln 5, ln 7)
# p81_q3: hyp (141.4 s,171.5 s), ref (142.5 s,171.2 s), overlap 28.8 of 28.8 s
# 	hyp (ln 11 m4.6, ln 15 m1.1), ref (ln 12, ln 14)
# p81_q4: hyp (169.7 s,199.4 s), ref (181.0 s,206.0 s), overlap 18.4 of 25.0 s
# 	hyp (ln 14 m4.3, ln 18 m1.5), ref (ln 16, ln 18)
# p81_q5: hyp (358.8 s,402.7 s), ref (370.1 s,398.5 s), overlap 28.4 of 28.4 s
# 	hyp (ln 35 m3.0, ln 40 m2.8), ref (ln 37, ln 39)
# p81_q6: hyp (222.2 s,266.3 s), ref (226.2 s,266.3 s), overlap 40.1 of 40.1 s
# 	hyp (ln 20 m5.7, ln 23 m6.0), ref (ln 21, ln 23)
# p81_q7: hyp (274.9 s,315.0 s), ref (278.3 s,315.4 s), overlap 36.8 of 37.1 s
# 	hyp (ln 24 m3.9, ln 27 m4.8), ref (ln 25, ln 27)
# p81_q8: hyp (298.3 s,331.5 s), ref (305.3 s,331.8 s), overlap 26.2 of 26.6 s
# 	hyp (ln 26 m2.7, ln 29 m4.8), ref (ln 27, ln 29)
# p81_q9: hyp (223.0 s,267.3 s), ref (398.5 s,417.5 s), overlap 0.0 of 19.0 s
# 	hyp (ln 20 m6.0, ln 24 m1.3), ref (ln 40, ln 41)
# p91_q1: hyp (138.4 s,164.0 s), ref (134.2 s,160.5 s), overlap 22.1 of 26.3 s
# 	hyp (ln 18 m2.6, ln 21 m2.5), ref (ln 18, ln 20)
# p91_q10: hyp (95.0 s,122.1 s), ref (93.6 s,117.8 s), overlap 22.8 of 24.2 s
# 	hyp (ln 13 m1.6, ln 16 m2.6), ref (ln 13, ln 15)
# p91_q2: hyp (156.1 s,178.3 s), ref (153.4 s,174.7 s), overlap 18.6 of 21.3 s
# 	hyp (ln 20 m2.1, ln 23 m2.6), ref (ln 20, ln 22)
# p91_q3: hyp (176.6 s,195.1 s), ref (174.7 s,189.7 s), overlap 13.1 of 15.1 s
# 	hyp (ln 23 m1.8, ln 25 m3.0), ref (ln 23, ln 24)
# p91_q4: hyp (194.7 s,215.8 s), ref (189.7 s,212.3 s), overlap 17.6 of 22.6 s
# 	hyp (ln 25 m2.8, ln 28 m2.6), ref (ln 25, ln 27)
# p91_q5: hyp (227.3 s,249.0 s), ref (225.2 s,244.2 s), overlap 16.9 of 19.0 s
# 	hyp (ln 30 m1.9, ln 33 m3.5), ref (ln 30, ln 32)
# p91_q6: hyp (0.0 s,23.9 s), ref (0.0 s,24.4 s), overlap 23.9 of 24.4 s
# 	hyp (ln 1 m1.0, ln 3 m3.8), ref (ln 1, ln 3)
# p91_q7: hyp (16.4 s,40.5 s), ref (16.4 s,39.9 s), overlap 23.5 of 23.5 s
# 	hyp (ln 3 m1.0, ln 6 m1.2), ref (ln 3, ln 5)
# p91_q8: hyp (40.8 s,64.3 s), ref (39.9 s,63.9 s), overlap 23.1 of 24.0 s
# 	hyp (ln 6 m1.3, ln 9 m1.1), ref (ln 6, ln 8)
# p91_q9: hyp (124.8 s,153.2 s), ref (63.9 s,85.8 s), overlap 0.0 of 21.9 s
# 	hyp (ln 16 m3.6, ln 19 m4.9), ref (ln 9, ln 11)
